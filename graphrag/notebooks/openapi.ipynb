# %%
pip install openapi3-parser
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from openapi_parser import parse
specification = parse('/data-transfer/openapi.json', strict_enum=False)

# %%
urls = [x.url for x in specification.paths]
#print (specification.paths)

# %%
for path in specification.paths:
#    supported_methods = ','.join([x.method.value for x in path.operations])

    #print(f"Operation: {path.url}, methods: {supported_methods}")
    for operation in path.operations:
        #print (operation.method.value)
        print (path.url)
        #print (operation.tags)
        #print ((operation.responses[0]))
        #print (path.tags)
        #print (path)
        for response in operation.responses:
            if (response.code==200):
                print((response.content[0].schema))
# Out:
# /api/codelists
# ...

# %%
# !head /data-transfer/openapi.
# Out:
# {
#    "openapi":"3.0.1",
#    "info":{
#       "title":"Datahub Codeprovider API",
#       "version": "1.0.0",
#       "description":"Codes, Replicated SAP CO (Custom Objects) data, GSDA, ConsumerViews",
#       "contact":{
#          "name":"Valletta",
#          "url":"https://confluence.bit.admin.ch/x/cBCxB",
#          "email":"devopsvalletta@ezv.admin.ch"

# %%
pip install openapi-spec-validator
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from openapi_spec_validator.readers import read_from_filename

spec_dict, base_uri = read_from_filename('/data-transfer/openapi.json')

# %%
from openapi_spec_validator import validate_spec
validate_spec(spec_dict)

# %%
validate_spec({'openapi': '3.1.0'})
# Out:
# ---------------------------------------------------------------------------
# OpenAPIValidationError                    Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 validate_spec({'openapi': '3.1.0'})
#
# File /opt/conda/lib/python3.11/site-packages/openapi_spec_validator/shortcuts.py:19, in validate_spec(spec, base_uri, validator, spec_url)
#      13 def validate_spec(
#      14     spec: Mapping[Hashable, Any],
#      15     base_uri: str = "",
#      16     validator: SupportsValidation = openapi_spec_validator_proxy,
#      17     spec_url: Optional[str] = None,
#      18 ) -> None:
# ---> 19     return validator.validate(spec, base_uri=base_uri, spec_url=spec_url)
#
# File /opt/conda/lib/python3.11/site-packages/openapi_spec_validator/validation/proxies.py:34, in DetectValidatorProxy.validate(self, instance, base_uri, spec_url)
#      30 validator = self.detect(instance)
#      31 for err in validator.iter_errors(
# ...
