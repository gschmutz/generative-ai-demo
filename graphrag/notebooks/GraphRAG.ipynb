# %%
# !pip3 install llama-index
# !pip3 install llama-index-core
# !pip3 install llama-index-embeddings-openai
# !pip3 install llama-parse
# !pip3 install neo4j
# !pip3 install llama-index-llms-ollama
# !pip3 install ollama
# Out:
# Requirement already satisfied: llama-index in /opt/conda/lib/python3.11/site-packages (0.10.36)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.2.4)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.1.12)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.35 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.10.36)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.1.9)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.13 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.1.19)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.1.22)
# Requirement already satisfied: llama-index-readers-llama-parse<0.2.0,>=0.1.2 in /opt/conda/lib/python3.11/site-packages (from llama-index) (0.1.4)
# Requirement already satisfied: openai>=1.14.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-agent-openai<0.3.0,>=0.1.4->llama-index) (1.29.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.35->llama-index) (2.0.22)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (0.6.6)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (2024.3.1)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (1.16.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.2.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /opt/conda/lib/python3.11/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse<0.5.0,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index) (0.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: pydantic>=1.10 in /opt/conda/lib/python3.11/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.35->llama-index) (2.7.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (4.0.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (0.14.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.35->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.35->llama-index) (2024.5.10)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.3.0,>=0.1.4->llama-index) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.35->llama-index) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.35->llama-index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.35->llama-index) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.35->llama-index) (3.21.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index) (2024.1)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.35->llama-index) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.35->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.35->llama-index) (2.18.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.16.0)
# Requirement already satisfied: llama-index-core in /opt/conda/lib/python3.11/site-packages (0.10.36)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.22)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (0.6.6)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (2024.3.1)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (1.29.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from llama-index-core) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.9.4)
# Requirement already satisfied: pydantic>=1.10 in /opt/conda/lib/python3.11/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core) (2.7.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core) (4.0.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core) (2024.5.10)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-core) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.11/site-packages (from dataclasses-json->llama-index-core) (3.21.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core) (2024.1)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core) (2.18.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core) (1.16.0)
# Requirement already satisfied: llama-index-embeddings-openai in /opt/conda/lib/python3.11/site-packages (0.1.9)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-embeddings-openai) (0.10.36)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.22)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.6)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.3.1)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.29.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.4)
# Requirement already satisfied: pydantic>=1.10 in /opt/conda/lib/python3.11/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.7.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.0.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.5.10)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.21.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.1)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.18.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.16.0)
# Requirement already satisfied: llama-parse in /opt/conda/lib/python3.11/site-packages (0.4.2)
# Requirement already satisfied: llama-index-core>=0.10.29 in /opt/conda/lib/python3.11/site-packages (from llama-parse) (0.10.36)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core>=0.10.29->llama-parse) (2.0.22)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.6.6)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (2024.3.1)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.29.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from llama-index-core>=0.10.29->llama-parse) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.10.29->llama-parse) (1.9.4)
# Requirement already satisfied: pydantic>=1.10 in /opt/conda/lib/python3.11/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core>=0.10.29->llama-parse) (2.7.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (4.0.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core>=0.10.29->llama-parse) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core>=0.10.29->llama-parse) (0.14.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core>=0.10.29->llama-parse) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core>=0.10.29->llama-parse) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core>=0.10.29->llama-parse) (2024.5.10)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-core>=0.10.29->llama-parse) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core>=0.10.29->llama-parse) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core>=0.10.29->llama-parse) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core>=0.10.29->llama-parse) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core>=0.10.29->llama-parse) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.11/site-packages (from dataclasses-json->llama-index-core>=0.10.29->llama-parse) (3.21.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core>=0.10.29->llama-parse) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core>=0.10.29->llama-parse) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core>=0.10.29->llama-parse) (2024.1)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core>=0.10.29->llama-parse) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core>=0.10.29->llama-parse) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core>=0.10.29->llama-parse) (2.18.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core>=0.10.29->llama-parse) (1.16.0)
# Requirement already satisfied: neo4j in /opt/conda/lib/python3.11/site-packages (5.20.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.11/site-packages (from neo4j) (2023.3.post1)
# Requirement already satisfied: llama-index-llms-ollama in /opt/conda/lib/python3.11/site-packages (0.1.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-llms-ollama) (0.10.36)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.0.22)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.6.6)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2024.3.1)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.29.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.9.4)
# Requirement already satisfied: pydantic>=1.10 in /opt/conda/lib/python3.11/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.7.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.0.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.14.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2024.5.10)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.21.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2024.1)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.18.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.16.0)
# Collecting ollama
#   Downloading ollama-0.2.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /opt/conda/lib/python3.11/site-packages (from ollama) (0.27.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (4.0.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Downloading ollama-0.2.0-py3-none-any.whl (9.5 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.2.0

# %%
# !wget 'https://raw.githubusercontent.com/Joshua-Yu/graph-rag/main/openai%2Bllamaparse/InjuredWorkerGuidebookCalifornia.pdf' -O './insurance.pdf'
# Out:
# --2024-05-13 19:23:16--  https://raw.githubusercontent.com/Joshua-Yu/graph-rag/main/openai%2Bllamaparse/InjuredWorkerGuidebookCalifornia.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3779314 (3.6M) [application/octet-stream]
# Saving to: ‘./insurance.pdf’
#
# ./insurance.pdf     100%[===================>]   3.60M  22.5MB/s    in 0.2s
#
# 2024-05-13 19:23:16 (22.5 MB/s) - ‘./insurance.pdf’ saved [3779314/3779314]

# %%
# llama-parse is async-first, running the async code in a notebook requires the use of nest_asyncio
import nest_asyncio
nest_asyncio.apply()

import os
# API access to llama-cloud
os.environ["LLAMA_CLOUD_API_KEY"] = "llx-dSMKpwu0fPsVOHfM3jxSsOYuMhS4ramkq9G1wjpQrHLZk9ny"

# Using OpenAI API for embeddings/llms
os.environ["OPENAI_API_KEY"] = "OPENAI-API-KEY"

# %%
# Just runs .complete to make sure the LLM is listening
from llama_index.llms.ollama import Ollama
from llama_index.core import Settings

llm = Ollama(model="llama3", base_url="http://192.168.1.102:11434")

response = llm.complete("Who is Laurie Voss? write in 10 words")
print(response)
# Out:
# Laurie Voss: Librarian, author, and advocate for school libraries.

# %%
from llama_index.llms.openai import OpenAI
#from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.ollama import Ollama
from llama_index.core import  VectorStoreIndex
from llama_index.core import Settings

EMBEDDING_MODEL  = "nomic-embed-text"
GENERATION_MODEL = "gpt-4"

#llm = OpenAI(model=GENERATION_MODEL)
llm = Ollama(model='llama3:8b', base_url="http://192.168.1.102:11434", request_timeout=120.0)

Settings.llm = llm

# %%
from llama_parse import LlamaParse

pdf_file_name = './insurance.pdf'

documents = LlamaParse(result_type="markdown").load_data(pdf_file_name)
# Out:
# Started parsing the file under job_id 24974054-19df-4dfc-8ecf-bd7e2dda07e6

# %%
# Check loaded documents

print(f"Number of documents: {len(documents)}")

for doc in documents:
    print(doc.doc_id)
    print(doc.text[:500] + '...')
# Out:
# Number of documents: 1
# 1b55563a-9858-4944-9f15-f8bb8c5db72a
# # Workers’ Compensation in California
#
# # A Guidebook for Injured Workers Sixth Edition April 2016
# ---
# # Workers’ Compensation in California
#
# A Guidebook for Injured Workers
#
# Sixth Edition
#
# April 2016
# ---
# This guidebook was designed and produced by the Office of the Director, Department of Industrial Relations (DIR), in consultation with the Division of Workers’ Compensation (DWC), State of California. It is based on the third edition of this guidebook, prepared in 2006 by the Institute for Resea...

# %%
# Parse the documents using MarkdownElementNodeParser

from llama_index.core.node_parser import MarkdownElementNodeParser

node_parser = MarkdownElementNodeParser(llm=llm, num_workers=1)

nodes = node_parser.get_nodes_from_documents(documents)
# Out:
# 42it [00:00, 95480.09it/s]
# 100%|██████████| 42/42 [06:45<00:00,  9.66s/it]

# %%
# Convert nodes into objects

base_nodes, objects = node_parser.get_nodes_and_objects(nodes)

# %%
import json


# Check parsed node objects 

print(f"Number of nodes: {len(base_nodes)}")
# Out:
# Number of nodes: 60

# %%
TABLE_REF_SUFFIX = '_table_ref'
TABLE_ID_SUFFIX  = '_table'

# Check parsed objects 

print(f"Number of objects: {len(objects)}")

for node in objects: 
    print(f"id:{node.node_id}")
    print(f"hash:{node.hash}")
    print(f"parent:{node.parent_node}")
    print(f"prev:{node.prev_node}")
    print(f"next:{node.next_node}")

    # Object is a Table
    if node.node_id[-1 * len(TABLE_REF_SUFFIX):] == TABLE_REF_SUFFIX:

        if node.next_node is not None:
            next_node = node.next_node
        
            print(f"next_node metadata:{next_node.metadata}")
            print(f"next_next_node:{next_next_nod_id}")

            obj_metadata = json.loads(str(next_node.json()))

            print(str(obj_metadata))

            print(f"def:{obj_metadata['metadata']['table_df']}")
            print(f"summary:{obj_metadata['metadata']['table_summary']}")


    print(f"next:{node.next_node}")
    print(f"type:{node.get_type()}")
    print(f"class:{node.class_name()}")
    print(f"content:{node.get_content()[:200]}")
    print(f"metadata:{node.metadata}")
    print(f"extra:{node.extra_info}")
    
    node_json = json.loads(node.json())

    print(f"start_idx:{node_json.get('start_char_idx')}")
    print(f"end_idx:{node_json['end_char_idx']}")

    if 'table_summary' in node_json: 
        print(f"summary:{node_json['table_summary']}")

    print("=====================================")
# Out:
# Number of objects: 42
# id:8abccb32-04dc-4eed-9c07-2d6ba7eb71e4
# hash:0319dbeff7961a93f93c7c05696e4f30c0ae9752bcfc3115a571e9825183877a
# parent:None
# prev:node_id='24b9bfb2-4a93-4cb3-ba87-38d824b8cee1' node_type=<ObjectType.TEXT: '1'> metadata={} hash='d452ba7d0bc7d1c574417b457f257d5bcc867d0fe5f7afe9c2902c2324930854'
# next:node_id='1099dbac-1c22-4501-8e4d-89ed4044ce1e' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What is workers’ compensation?': {0: 'What are the benefits?', 1: 'Can my regular doctor treat me if I get hurt on the job?', 2: 'Can all workers predesignate?', 3: 'How to predesignate', 4: 'Are there different rules for predesignating if my employer or the insurer has a contract with a health care organization (HCO)?', 5: 'What should I do if I get hurt at work or develop a work-related medical problem?', 6: 'How can I avoid getting hurt on the job?', 7: 'Workers’ Compensation Benefits—Examples'}, '2': {0: 2, 1: 2, 2: 3, 3: 3, 4: 4, 5: 4, 6: 4, 7: 5}}", 'table_summary': "Based on the provided context, I would summarize the table as:\n\n**Table Summary:** This table provides information about workers' compensation, including its definition, benefits, and related procedures.\n\n**Existing Table Title/Caption:** Not provided in the given context.\n\n**Table ID:** Not specified in the provided context.\n\n**Should the table be kept?**: Yes, the table should be retained as it appears to contain important information relevant to understanding workers' compensation.,\nwith the following columns:\n"} hash='aa34d707c47b381d974f3f091303f0d4d8285e305af76512ce0e5ab22a5b4d9d'
# next:node_id='1099dbac-1c22-4501-8e4d-89ed4044ce1e' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What is workers’ compensation?': {0: 'What are the benefits?', 1: 'Can my regular doctor treat me if I get hurt on the job?', 2: 'Can all workers predesignate?', 3: 'How to predesignate', 4: 'Are there different rules for predesignating if my employer or the insurer has a contract with a health care organization (HCO)?', 5: 'What should I do if I get hurt at work or develop a work-related medical problem?', 6: 'How can I avoid getting hurt on the job?', 7: 'Workers’ Compensation Benefits—Examples'}, '2': {0: 2, 1: 2, 2: 3, 3: 3, 4: 4, 5: 4, 6: 4, 7: 5}}", 'table_summary': "Based on the provided context, I would summarize the table as:\n\n**Table Summary:** This table provides information about workers' compensation, including its definition, benefits, and related procedures.\n\n**Existing Table Title/Caption:** Not provided in the given context.\n\n**Table ID:** Not specified in the provided context.\n\n**Should the table be kept?**: Yes, the table should be retained as it appears to contain important information relevant to understanding workers' compensation.,\nwith the following columns:\n"} hash='aa34d707c47b381d974f3f091303f0d4d8285e305af76512ce0e5ab22a5b4d9d'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the provided context, I would summarize the table as:
#
# **Table Summary:** This table provides information about workers' compensation, including its definition, benefits, and related procedur
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:2425
# end_idx:2923
# =====================================
# id:b964b8bf-43b1-48b5-95c0-e1f9bdce1d02
# hash:e1e107c70823dce163cf6b4e9b57bacd3ee3a2a08f12008c07de1671c5c56138
# parent:None
# prev:node_id='d2de6ea3-4de0-4e8d-ba0c-c2d7a81fe90b' node_type=<ObjectType.TEXT: '1'> metadata={} hash='9eef9cdec56a1093f8431c1307235788e92deec1705606ffbf893c3165df9ecf'
# next:node_id='b133622e-f422-4405-a836-db491fdc062f' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What should I do after reporting my injury or illness to my employer?': {0: 'What happens after I file the claim form?', 1: 'If I haven’t heard from the claims administrator, is my claim accepted?', 2: 'Who decides what type of work I can do while recovering?', 3: 'I’m afraid I might be fired because of my injury. Can my employer fire me?', 4: 'Besides workers’ compensation benefits, can I get any other financial assistance?', 5: 'Keep your claim on track'}, '6': {0: 6, 1: 7, 2: 7, 3: 8, 4: 8, 5: 9}}", 'table_summary': 'Based on the given context information, it appears that this table is about guiding employees through the process of reporting an injury or illness to their employer and what to expect afterwards.\n\n**Summary:** Workers\' compensation benefits and recovery guidance.\n\n**Table Title/Caption:** "What to Expect After Reporting Your Injury"\n\n**Table ID:** 5\n\n**Should be kept:** Yes, this information appears to be relevant and helpful for employees navigating the workers\' compensation process.,\nwith the following columns:\n'} hash='5b8814be94091940b4dc845978903f5b138ec8cbd50580fe8f0255cdd71e9b28'
# next:node_id='b133622e-f422-4405-a836-db491fdc062f' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What should I do after reporting my injury or illness to my employer?': {0: 'What happens after I file the claim form?', 1: 'If I haven’t heard from the claims administrator, is my claim accepted?', 2: 'Who decides what type of work I can do while recovering?', 3: 'I’m afraid I might be fired because of my injury. Can my employer fire me?', 4: 'Besides workers’ compensation benefits, can I get any other financial assistance?', 5: 'Keep your claim on track'}, '6': {0: 6, 1: 7, 2: 7, 3: 8, 4: 8, 5: 9}}", 'table_summary': 'Based on the given context information, it appears that this table is about guiding employees through the process of reporting an injury or illness to their employer and what to expect afterwards.\n\n**Summary:** Workers\' compensation benefits and recovery guidance.\n\n**Table Title/Caption:** "What to Expect After Reporting Your Injury"\n\n**Table ID:** 5\n\n**Should be kept:** Yes, this information appears to be relevant and helpful for employees navigating the workers\' compensation process.,\nwith the following columns:\n'} hash='5b8814be94091940b4dc845978903f5b138ec8cbd50580fe8f0255cdd71e9b28'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the given context information, it appears that this table is about guiding employees through the process of reporting an injury or illness to their employer and what to expect afterwards.
#
# **
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:2969
# end_idx:3429
# =====================================
# id:580847df-0053-464b-804b-750002f00697
# hash:b5dc90d80be3e118eaaf19892fa6a2a1624adc8bb243dff80b6940f587efa98b
# parent:None
# prev:node_id='412cc5a3-afbf-4f5d-aba8-6acae46084f9' node_type=<ObjectType.TEXT: '1'> metadata={} hash='4714556225a76c3107173667b92e8c0c2df71c767390a0b80b97f0a097274422'
# next:node_id='792266cd-9ad0-42d7-9a06-bd2decddf87f' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Who pays for my medical care?': {0: 'What kind of medical care is available to injured workers?', 1: 'When does my medical care start?', 2: 'What should I do if the claims administrator does not authorize treatment right away?', 3: 'For non-emergency care, who can treat me right after I am injured?', 4: 'Can I switch to a different doctor for treatment?', 5: 'How can I avoid problems in getting appropriate treatment?'}, '10': {0: 10, 1: 11, 2: 11, 3: 12, 4: 13, 5: 14}}", 'table_summary': 'Based on the given context, I would summarize the table as:\n\n**Table Summary:** Medical benefits and treatment options for injured workers.\n\n**Existing Table Title/Caption:** (Not provided)\n\n**Table ID:** Not applicable (since no ID is provided)\n\n**Should this table be kept?**: Yes, it appears to provide important information about medical care and treatment options for individuals who have been injured.,\nwith the following columns:\n'} hash='f6e0f26ba170774cbd1207a9451b14e1a61fa052e7118a0fba615e6f854909e9'
# next:node_id='792266cd-9ad0-42d7-9a06-bd2decddf87f' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Who pays for my medical care?': {0: 'What kind of medical care is available to injured workers?', 1: 'When does my medical care start?', 2: 'What should I do if the claims administrator does not authorize treatment right away?', 3: 'For non-emergency care, who can treat me right after I am injured?', 4: 'Can I switch to a different doctor for treatment?', 5: 'How can I avoid problems in getting appropriate treatment?'}, '10': {0: 10, 1: 11, 2: 11, 3: 12, 4: 13, 5: 14}}", 'table_summary': 'Based on the given context, I would summarize the table as:\n\n**Table Summary:** Medical benefits and treatment options for injured workers.\n\n**Existing Table Title/Caption:** (Not provided)\n\n**Table ID:** Not applicable (since no ID is provided)\n\n**Should this table be kept?**: Yes, it appears to provide important information about medical care and treatment options for individuals who have been injured.,\nwith the following columns:\n'} hash='f6e0f26ba170774cbd1207a9451b14e1a61fa052e7118a0fba615e6f854909e9'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the given context, I would summarize the table as:
#
# **Table Summary:** Medical benefits and treatment options for injured workers.
#
# **Existing Table Title/Caption:** (Not provided)
#
# **Table I
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:3458
# end_idx:3886
# =====================================
# id:23fa16e4-c3cb-41d3-b838-aeebe90fa83b
# hash:3cc14e1feef715179e87c0d536fda9a905d0257d5c9ffe9f7b5203484ad2d0fa
# parent:None
# prev:node_id='a22c0124-aa6c-4417-919e-d02b5aefbd1b' node_type=<ObjectType.TEXT: '1'> metadata={} hash='22a7ce2954a90f3267992e7d97d31b77110dca358703751aa35ae14c115fc4a5'
# next:node_id='35886c39-532c-40fe-98d0-13536c3e800b' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Chapter 4. Resolving Problems with Medical Care & Medical Reports': {0: 'I don’t agree with a medical report written by my primary treating physician or other treating doctor. What can I do?', 1: 'What can I do if I don’t agree with the doctor about necessary treatment?', 2: 'How to Get a Medical Evaluation', 3: 'I agree with a treating doctor about necessary treatment. How long can the claims administrator take to decide whether to authorize treatment?', 4: 'Can treatment recommended by a treating doctor be denied?', 5: 'I don’t agree with a decision to deny treatment. What can I do?', 6: 'What can I do if I don’t agree with a treating doctor on matters other than treatment?', 7: 'If the claims administrator doesn’t agree with a treating doctor on matters other than treatment, what can the claims administrator do?'}, '15': {0: 15, 1: 15, 2: 17, 3: 18, 4: 19, 5: 19, 6: 20, 7: 20}}", 'table_summary': 'Summary: This table provides guidance on resolving issues with medical care and reports, including disputing medical reports, seeking alternative opinions, and appealing treatment denials.\n\nTable Title/Caption: Chapter 4. Resolving Problems with Medical Care & Medical Reports\nTable ID: 15\nShould the table be kept? Yes,\nwith the following columns:\n'} hash='03c16fe404eba993cdf240eab712cacb43373f781c0272b9b70e5f2399b15102'
# next:node_id='35886c39-532c-40fe-98d0-13536c3e800b' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Chapter 4. Resolving Problems with Medical Care & Medical Reports': {0: 'I don’t agree with a medical report written by my primary treating physician or other treating doctor. What can I do?', 1: 'What can I do if I don’t agree with the doctor about necessary treatment?', 2: 'How to Get a Medical Evaluation', 3: 'I agree with a treating doctor about necessary treatment. How long can the claims administrator take to decide whether to authorize treatment?', 4: 'Can treatment recommended by a treating doctor be denied?', 5: 'I don’t agree with a decision to deny treatment. What can I do?', 6: 'What can I do if I don’t agree with a treating doctor on matters other than treatment?', 7: 'If the claims administrator doesn’t agree with a treating doctor on matters other than treatment, what can the claims administrator do?'}, '15': {0: 15, 1: 15, 2: 17, 3: 18, 4: 19, 5: 19, 6: 20, 7: 20}}", 'table_summary': 'Summary: This table provides guidance on resolving issues with medical care and reports, including disputing medical reports, seeking alternative opinions, and appealing treatment denials.\n\nTable Title/Caption: Chapter 4. Resolving Problems with Medical Care & Medical Reports\nTable ID: 15\nShould the table be kept? Yes,\nwith the following columns:\n'} hash='03c16fe404eba993cdf240eab712cacb43373f781c0272b9b70e5f2399b15102'
# type:ObjectType.INDEX
# class:IndexNode
# content:Summary: This table provides guidance on resolving issues with medical care and reports, including disputing medical reports, seeking alternative opinions, and appealing treatment denials.
#
# Table Titl
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:3936
# end_idx:4768
# =====================================
# id:5bb6ec3d-62c8-44ca-98f0-70d3f1dcf13f
# hash:cb4543aea95dbbb7f9c80dae94532d368295e278f65295b93e1a7cc6ea0726cb
# parent:None
# prev:node_id='35886c39-532c-40fe-98d0-13536c3e800b' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Chapter 4. Resolving Problems with Medical Care & Medical Reports': {0: 'I don’t agree with a medical report written by my primary treating physician or other treating doctor. What can I do?', 1: 'What can I do if I don’t agree with the doctor about necessary treatment?', 2: 'How to Get a Medical Evaluation', 3: 'I agree with a treating doctor about necessary treatment. How long can the claims administrator take to decide whether to authorize treatment?', 4: 'Can treatment recommended by a treating doctor be denied?', 5: 'I don’t agree with a decision to deny treatment. What can I do?', 6: 'What can I do if I don’t agree with a treating doctor on matters other than treatment?', 7: 'If the claims administrator doesn’t agree with a treating doctor on matters other than treatment, what can the claims administrator do?'}, '15': {0: 15, 1: 15, 2: 17, 3: 18, 4: 19, 5: 19, 6: 20, 7: 20}}", 'table_summary': 'Summary: This table provides guidance on resolving issues with medical care and reports, including disputing medical reports, seeking alternative opinions, and appealing treatment denials.\n\nTable Title/Caption: Chapter 4. Resolving Problems with Medical Care & Medical Reports\nTable ID: 15\nShould the table be kept? Yes,\nwith the following columns:\n'} hash='03c16fe404eba993cdf240eab712cacb43373f781c0272b9b70e5f2399b15102'
# next:node_id='e08412f8-876c-4116-9bf8-1767d655187c' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Chapter 5. Temporary Disability Benefits': {0: 'What are temporary disability benefits?', 1: 'What are the different types of TD benefits?', 2: 'How much are TD benefits?', 3: 'What payments do I receive if I’m on TTD?', 4: 'What payments do I receive if I’m on TPD?', 5: 'When do TD payments begin?', 6: 'What happens if I don’t get my payments on time?', 7: 'Is the claims administrator required to pay a penalty for delays in TD payments?', 8: 'When do TD payments end?', 9: 'Temporary Total Disability Payments — Some Examples'}, '21': {0: 21, 1: 21, 2: 21, 3: 22, 4: 23, 5: 23, 6: 24, 7: 24, 8: 25, 9: 25}}", 'table_summary': 'Based on the given context information, I would summarize this table as:\n\n"This table provides an overview of Temporary Disability Benefits (TD) payments, including definitions, types, and payment schedules."\n\nThe existing table title/caption is:\n"Chapter 5. Temporary Disability Benefits"\n\nThe existing table id is:\n"(Table 5)"\n\nAs for whether the table should be kept, I would say **yes**, as it appears to provide important information about a specific topic (Temporary Disability Benefits) that may be useful to readers or users.,\nwith the following columns:\n'} hash='6e382db889db64032c4ec97cbe33853be65e17894dc6b02996622b4da56fb655'
# next:node_id='e08412f8-876c-4116-9bf8-1767d655187c' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Chapter 5. Temporary Disability Benefits': {0: 'What are temporary disability benefits?', 1: 'What are the different types of TD benefits?', 2: 'How much are TD benefits?', 3: 'What payments do I receive if I’m on TTD?', 4: 'What payments do I receive if I’m on TPD?', 5: 'When do TD payments begin?', 6: 'What happens if I don’t get my payments on time?', 7: 'Is the claims administrator required to pay a penalty for delays in TD payments?', 8: 'When do TD payments end?', 9: 'Temporary Total Disability Payments — Some Examples'}, '21': {0: 21, 1: 21, 2: 21, 3: 22, 4: 23, 5: 23, 6: 24, 7: 24, 8: 25, 9: 25}}", 'table_summary': 'Based on the given context information, I would summarize this table as:\n\n"This table provides an overview of Temporary Disability Benefits (TD) payments, including definitions, types, and payment schedules."\n\nThe existing table title/caption is:\n"Chapter 5. Temporary Disability Benefits"\n\nThe existing table id is:\n"(Table 5)"\n\nAs for whether the table should be kept, I would say **yes**, as it appears to provide important information about a specific topic (Temporary Disability Benefits) that may be useful to readers or users.,\nwith the following columns:\n'} hash='6e382db889db64032c4ec97cbe33853be65e17894dc6b02996622b4da56fb655'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the given context information, I would summarize this table as:
#
# "This table provides an overview of Temporary Disability Benefits (TD) payments, including definitions, types, and payment sch
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:4770
# end_idx:5304
# =====================================
# id:69044a6e-c2e3-4500-a541-8af13aaef78d
# hash:423826307dc155e1d414053454c05e4c96a7ff495e1ce0b4e3469fe2aac7690c
# parent:None
# prev:node_id='e08412f8-876c-4116-9bf8-1767d655187c' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Chapter 5. Temporary Disability Benefits': {0: 'What are temporary disability benefits?', 1: 'What are the different types of TD benefits?', 2: 'How much are TD benefits?', 3: 'What payments do I receive if I’m on TTD?', 4: 'What payments do I receive if I’m on TPD?', 5: 'When do TD payments begin?', 6: 'What happens if I don’t get my payments on time?', 7: 'Is the claims administrator required to pay a penalty for delays in TD payments?', 8: 'When do TD payments end?', 9: 'Temporary Total Disability Payments — Some Examples'}, '21': {0: 21, 1: 21, 2: 21, 3: 22, 4: 23, 5: 23, 6: 24, 7: 24, 8: 25, 9: 25}}", 'table_summary': 'Based on the given context information, I would summarize this table as:\n\n"This table provides an overview of Temporary Disability Benefits (TD) payments, including definitions, types, and payment schedules."\n\nThe existing table title/caption is:\n"Chapter 5. Temporary Disability Benefits"\n\nThe existing table id is:\n"(Table 5)"\n\nAs for whether the table should be kept, I would say **yes**, as it appears to provide important information about a specific topic (Temporary Disability Benefits) that may be useful to readers or users.,\nwith the following columns:\n'} hash='6e382db889db64032c4ec97cbe33853be65e17894dc6b02996622b4da56fb655'
# next:node_id='23285f0e-67b4-47c7-8506-bbc189220d5d' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Chapter 6. Working for Your Employer After Injury': {0: 'Can I stay at work or return to work, and what work can I do?', 1: 'What happens while I am recovering?', 2: 'My employer assigned work that seems to violate my work restrictions. What can I do?', 3: 'What happens if I don’t fully recover?', 4: 'Can I return to work for my employer even if I don’t fully recover?', 5: 'My employer will not offer or assign me the kind of work that I want. What can I do?'}, '26': {0: 26, 1: 26, 2: 27, 3: 27, 4: 28, 5: 30}}", 'table_summary': 'Based on the given context, I would summarize the table as:\n\n"This table provides guidance on working for an employer after sustaining an injury, covering topics such as staying at work, returning to work, and handling work restrictions."\n\nThe real/existing table title/caption is:\n"Chapter 6. Working for Your Employer After Injury"\n\nThe real/existing table id is: #26\n\nIn my opinion, this table should be kept.,\nwith the following columns:\n'} hash='b84b174aa583913bbd1d275dfe925bca6aab1ed34039ef2068bfdf6c4c42df87'
# next:node_id='23285f0e-67b4-47c7-8506-bbc189220d5d' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Chapter 6. Working for Your Employer After Injury': {0: 'Can I stay at work or return to work, and what work can I do?', 1: 'What happens while I am recovering?', 2: 'My employer assigned work that seems to violate my work restrictions. What can I do?', 3: 'What happens if I don’t fully recover?', 4: 'Can I return to work for my employer even if I don’t fully recover?', 5: 'My employer will not offer or assign me the kind of work that I want. What can I do?'}, '26': {0: 26, 1: 26, 2: 27, 3: 27, 4: 28, 5: 30}}", 'table_summary': 'Based on the given context, I would summarize the table as:\n\n"This table provides guidance on working for an employer after sustaining an injury, covering topics such as staying at work, returning to work, and handling work restrictions."\n\nThe real/existing table title/caption is:\n"Chapter 6. Working for Your Employer After Injury"\n\nThe real/existing table id is: #26\n\nIn my opinion, this table should be kept.,\nwith the following columns:\n'} hash='b84b174aa583913bbd1d275dfe925bca6aab1ed34039ef2068bfdf6c4c42df87'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the given context, I would summarize the table as:
#
# "This table provides guidance on working for an employer after sustaining an injury, covering topics such as staying at work, returning to
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:5306
# end_idx:5775
# =====================================
# id:4c61cc0e-f113-4477-ad49-17a12b68ffbd
# hash:af3c8b1fce9d0a6b477ac0e19f1119565369d6fc39cf31b1266514be70da91c6
# parent:None
# prev:node_id='2391eee2-7aa9-4066-bcad-46b9abbf5a34' node_type=<ObjectType.TEXT: '1'> metadata={} hash='f19a0bb9c026c8d52e1099920d2ffb627fad7cfb3f504feb9c800d87b210cfeb'
# next:node_id='47b524c3-30ef-41d3-b05f-b7744e121653' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What are permanent disability benefits?': {0: 'What is a P&S report?', 1: 'I don’t agree with the P&S report. What can I do?', 2: 'What is a rating?', 3: 'How is my disability rated?', 4: 'I disagree with the rating by the claims administrator. What can I do?', 5: 'I disagree with the rating by the disability rater. What can I do?', 6: 'How are PD payments determined?', 7: 'When do I receive PD payments?', 8: 'How are my PD payments affected if my employer does or doesn’t offer me work?', 9: 'Is the claims administrator required to pay a penalty for delays in PD payments?', 10: 'Can my case be settled?', 11: 'What if I don’t agree with the claims administrator’s settlement offers?'}, '31': {0: 31, 1: 32, 2: 32, 3: 33, 4: 33, 5: 34, 6: 34, 7: 35, 8: 36, 9: 36, 10: 37, 11: 37}}", 'table_summary': 'Based on the context information, it appears that this table is about Permanent Disability (PD) benefits and the process of applying for and receiving them.\n\nCaption/Summary: "Permanent Disability Benefits Process"\n\nTable Title/Caption: None provided\n\nTable ID: [None provided]\n\nShould the table be kept? Yes. The table provides a clear outline of the steps involved in seeking permanent disability benefits, which can be helpful for individuals navigating this process.,\nwith the following columns:\n'} hash='45e5779bc0d2c34fa014d8ae0b8e275e27463c2a88bd0cd08cb34f4121670ff9'
# next:node_id='47b524c3-30ef-41d3-b05f-b7744e121653' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What are permanent disability benefits?': {0: 'What is a P&S report?', 1: 'I don’t agree with the P&S report. What can I do?', 2: 'What is a rating?', 3: 'How is my disability rated?', 4: 'I disagree with the rating by the claims administrator. What can I do?', 5: 'I disagree with the rating by the disability rater. What can I do?', 6: 'How are PD payments determined?', 7: 'When do I receive PD payments?', 8: 'How are my PD payments affected if my employer does or doesn’t offer me work?', 9: 'Is the claims administrator required to pay a penalty for delays in PD payments?', 10: 'Can my case be settled?', 11: 'What if I don’t agree with the claims administrator’s settlement offers?'}, '31': {0: 31, 1: 32, 2: 32, 3: 33, 4: 33, 5: 34, 6: 34, 7: 35, 8: 36, 9: 36, 10: 37, 11: 37}}", 'table_summary': 'Based on the context information, it appears that this table is about Permanent Disability (PD) benefits and the process of applying for and receiving them.\n\nCaption/Summary: "Permanent Disability Benefits Process"\n\nTable Title/Caption: None provided\n\nTable ID: [None provided]\n\nShould the table be kept? Yes. The table provides a clear outline of the steps involved in seeking permanent disability benefits, which can be helpful for individuals navigating this process.,\nwith the following columns:\n'} hash='45e5779bc0d2c34fa014d8ae0b8e275e27463c2a88bd0cd08cb34f4121670ff9'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the context information, it appears that this table is about Permanent Disability (PD) benefits and the process of applying for and receiving them.
#
# Caption/Summary: "Permanent Disability Ben
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:5836
# end_idx:6525
# =====================================
# id:50f02a90-f262-4c89-ac8e-5bb110626f04
# hash:3c50319b5089c015257244364a1d9a21e6da66a1eebb322c9326384206a340c8
# parent:None
# prev:node_id='555863e7-595e-48b8-a41f-195b12f2c5d1' node_type=<ObjectType.TEXT: '1'> metadata={} hash='9e9b02892f2901ade3255c2bff296c127a9d2d443544efc764babac81c258b1b'
# next:node_id='ecc5cba5-40af-4352-a910-bfd6ed2c064b' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What is a supplemental job displacement benefit?': {0: 'What is the dollar amount of this benefit?', 1: 'How can I obtain this benefit?', 2: 'When do I receive the voucher?', 3: 'What schools can I attend?', 4: 'What vocational or return-to-work counselors can I use?', 5: 'How do I use the voucher to pay for expenses?', 6: 'Is there a deadline for using the voucher?', 7: 'I have a problem with my supplemental job displacement benefit. What can I do?'}, '38': {0: 38, 1: 38, 2: 39, 3: 39, 4: 39, 5: 39, 6: 39, 7: 39}}", 'table_summary': 'Based on the provided context information, here is a concise summary of what the table is about:\n\n**Summary:** This table provides information about the Supplemental Job Displacement Benefit program, including its purpose, eligibility, and usage details.\n\n**Table Title/Caption:** "Supplemental Job Displacement Benefit Information"\n\n**Table ID:** 38-39\n\n**Should the Table be Kept?:** Yes, this table should be kept as it provides essential information about a specific benefit program that individuals may find valuable.,\nwith the following columns:\n'} hash='68a5d2d6f65510f01498adef62f0883ec769c3f5956ba52d6b90d1f115b34a92'
# next:node_id='ecc5cba5-40af-4352-a910-bfd6ed2c064b' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What is a supplemental job displacement benefit?': {0: 'What is the dollar amount of this benefit?', 1: 'How can I obtain this benefit?', 2: 'When do I receive the voucher?', 3: 'What schools can I attend?', 4: 'What vocational or return-to-work counselors can I use?', 5: 'How do I use the voucher to pay for expenses?', 6: 'Is there a deadline for using the voucher?', 7: 'I have a problem with my supplemental job displacement benefit. What can I do?'}, '38': {0: 38, 1: 38, 2: 39, 3: 39, 4: 39, 5: 39, 6: 39, 7: 39}}", 'table_summary': 'Based on the provided context information, here is a concise summary of what the table is about:\n\n**Summary:** This table provides information about the Supplemental Job Displacement Benefit program, including its purpose, eligibility, and usage details.\n\n**Table Title/Caption:** "Supplemental Job Displacement Benefit Information"\n\n**Table ID:** 38-39\n\n**Should the Table be Kept?:** Yes, this table should be kept as it provides essential information about a specific benefit program that individuals may find valuable.,\nwith the following columns:\n'} hash='68a5d2d6f65510f01498adef62f0883ec769c3f5956ba52d6b90d1f115b34a92'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the provided context information, here is a concise summary of what the table is about:
#
# **Summary:** This table provides information about the Supplemental Job Displacement Benefit program,
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:6618
# end_idx:7077
# =====================================
# id:9599a5f1-4bf7-436d-b5e9-01c2d9e3756d
# hash:4535fdcc4ea58b8299d9e42310e37bd1995a42046c6c13bca8b98e02a67f9286
# parent:None
# prev:node_id='705942ba-8966-4fc2-b2dd-4579518a73cb' node_type=<ObjectType.TEXT: '1'> metadata={} hash='6e4778188c9a00bdb488b4bd99c9876b0ff0672d4244cd25312249c4880dadc0'
# next:node_id='78f6d1ef-316f-492e-8e82-c197b7536547' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What is a supplemental job displacement benefit?': {0: 'What is the dollar amount of this benefit?', 1: 'How can I obtain this benefit?', 2: 'When do I receive the voucher?', 3: 'What schools can I attend?', 4: 'What vocational or return-to-work counselors can I use?', 5: 'How do I use the voucher to pay for expenses?'}, '40': {0: 40, 1: 40, 2: 40, 3: 41, 4: 41, 5: 41}}", 'table_summary': 'Based on the provided context information, I would summarize this table as:\n\n**Summary:** This table provides information about supplemental job displacement benefits, including its definition, eligibility, and usage details.\n\n**Table Title/Caption:** Supplemental Job Displacement Benefits Information\n\n**Table ID:** (Not specified)\n\n**Should the table be kept?**: Yes, the table should be kept as it appears to provide important information related to a specific topic or program.,\nwith the following columns:\n'} hash='3ddb95e93ae1b535ab3f766178b0e891a050a6f1d2932ada3bee7755536c0f54'
# next:node_id='78f6d1ef-316f-492e-8e82-c197b7536547' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'What is a supplemental job displacement benefit?': {0: 'What is the dollar amount of this benefit?', 1: 'How can I obtain this benefit?', 2: 'When do I receive the voucher?', 3: 'What schools can I attend?', 4: 'What vocational or return-to-work counselors can I use?', 5: 'How do I use the voucher to pay for expenses?'}, '40': {0: 40, 1: 40, 2: 40, 3: 41, 4: 41, 5: 41}}", 'table_summary': 'Based on the provided context information, I would summarize this table as:\n\n**Summary:** This table provides information about supplemental job displacement benefits, including its definition, eligibility, and usage details.\n\n**Table Title/Caption:** Supplemental Job Displacement Benefits Information\n\n**Table ID:** (Not specified)\n\n**Should the table be kept?**: Yes, the table should be kept as it appears to provide important information related to a specific topic or program.,\nwith the following columns:\n'} hash='3ddb95e93ae1b535ab3f766178b0e891a050a6f1d2932ada3bee7755536c0f54'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the provided context information, I would summarize this table as:
#
# **Summary:** This table provides information about supplemental job displacement benefits, including its definition, eligib
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:7113
# end_idx:7440
# =====================================
# id:67a4c93e-5157-449c-8ce9-768cae82bb35
# hash:375f9f198833e772061c0ddc37fd38418d8ab01572a8218c6cdaf702f7e5c2dc
# parent:None
# prev:node_id='ab893568-4df5-448f-a6f6-c6a38b8b30a5' node_type=<ObjectType.TEXT: '1'> metadata={} hash='22a7ce2954a90f3267992e7d97d31b77110dca358703751aa35ae14c115fc4a5'
# next:node_id='253b5226-f9a1-4a02-aec0-c1218428a24d' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Is there a deadline for using the voucher?': {0: 'I have a problem with my supplemental job displacement benefit. What can I do?', 1: 'Chapter 9. Return-to-Work Supplement Program', 2: 'Who is eligible for a Return-to-Work Supplement?', 3: 'What is the deadline for applying?', 4: 'What is the dollar amount of the Return-to-Work Supplement?', 5: 'How do I apply for the supplement?', 6: 'What information do I need to complete an application (other than name, address, and phone number)?', 7: 'What happens after I submit my application?', 8: 'What if I disagree with the RTWSP’s eligibility decision?', 9: 'Chapter 10. For More Information and Help', 10: 'Your Employer', 11: 'The Claims Administrator', 12: 'Division of Workers’ Compensation', 13: 'Commission on Health and Safety and Workers’ Compensation (CHSWC)', 14: 'Applicants’ Attorneys', 15: 'Your Primary Treating Physician', 16: 'Labor Organizations', 17: 'Occupational Health Clinics', 18: 'Health & Safety Agencies & Organizations', 19: 'Other State and Federal Agencies—Financial Assistance', 20: 'Other State and Federal Agencies—Discrimination Complaints', 21: 'Books and Other Materials', 22: 'Questions & Answers About Information & Assistance Services', 23: 'Division of Workers’ Compensation (DWC) Information & Assistance Offices', 24: 'Questions & Answers About Attorneys', 25: 'Appendix A. Important Laws & Regulations', 26: 'Appendix B. Glossary'}, '41': {0: 41, 1: 42, 2: 42, 3: 42, 4: 42, 5: 42, 6: 43, 7: 43, 8: 43, 9: 44, 10: 44, 11: 44, 12: 44, 13: 45, 14: 45, 15: 45, 16: 45, 17: 45, 18: 45, 19: 46, 20: 46, 21: 47, 22: 48, 23: 49, 24: 50, 25: 51, 26: 56}}", 'table_summary': 'Based on the given context information, it appears that this table is a contents page or an index of various topics and resources related to worker\'s compensation and supplemental job displacement benefits.\n\n**Summary:** Table of Contents for Worker\'s Compensation and Supplemental Job Displacement Benefits Information and Resources.\n\n**Existing Table Title/Caption:** "Table of Contents"\n\n**Table ID:** 41\n\n**Should the table be kept?**: Yes, as it serves as a useful navigation tool for users to quickly locate specific information and resources related to worker\'s compensation and supplemental job displacement benefits.,\nwith the following columns:\n'} hash='7da5d6459b7083ddb62124353c42eed80b14efae7459d7bb190199b3ac053871'
# next:node_id='253b5226-f9a1-4a02-aec0-c1218428a24d' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Is there a deadline for using the voucher?': {0: 'I have a problem with my supplemental job displacement benefit. What can I do?', 1: 'Chapter 9. Return-to-Work Supplement Program', 2: 'Who is eligible for a Return-to-Work Supplement?', 3: 'What is the deadline for applying?', 4: 'What is the dollar amount of the Return-to-Work Supplement?', 5: 'How do I apply for the supplement?', 6: 'What information do I need to complete an application (other than name, address, and phone number)?', 7: 'What happens after I submit my application?', 8: 'What if I disagree with the RTWSP’s eligibility decision?', 9: 'Chapter 10. For More Information and Help', 10: 'Your Employer', 11: 'The Claims Administrator', 12: 'Division of Workers’ Compensation', 13: 'Commission on Health and Safety and Workers’ Compensation (CHSWC)', 14: 'Applicants’ Attorneys', 15: 'Your Primary Treating Physician', 16: 'Labor Organizations', 17: 'Occupational Health Clinics', 18: 'Health & Safety Agencies & Organizations', 19: 'Other State and Federal Agencies—Financial Assistance', 20: 'Other State and Federal Agencies—Discrimination Complaints', 21: 'Books and Other Materials', 22: 'Questions & Answers About Information & Assistance Services', 23: 'Division of Workers’ Compensation (DWC) Information & Assistance Offices', 24: 'Questions & Answers About Attorneys', 25: 'Appendix A. Important Laws & Regulations', 26: 'Appendix B. Glossary'}, '41': {0: 41, 1: 42, 2: 42, 3: 42, 4: 42, 5: 42, 6: 43, 7: 43, 8: 43, 9: 44, 10: 44, 11: 44, 12: 44, 13: 45, 14: 45, 15: 45, 16: 45, 17: 45, 18: 45, 19: 46, 20: 46, 21: 47, 22: 48, 23: 49, 24: 50, 25: 51, 26: 56}}", 'table_summary': 'Based on the given context information, it appears that this table is a contents page or an index of various topics and resources related to worker\'s compensation and supplemental job displacement benefits.\n\n**Summary:** Table of Contents for Worker\'s Compensation and Supplemental Job Displacement Benefits Information and Resources.\n\n**Existing Table Title/Caption:** "Table of Contents"\n\n**Table ID:** 41\n\n**Should the table be kept?**: Yes, as it serves as a useful navigation tool for users to quickly locate specific information and resources related to worker\'s compensation and supplemental job displacement benefits.,\nwith the following columns:\n'} hash='7da5d6459b7083ddb62124353c42eed80b14efae7459d7bb190199b3ac053871'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the given context information, it appears that this table is a contents page or an index of various topics and resources related to worker's compensation and supplemental job displacement ben
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:7490
# end_idx:8881
# =====================================
# id:8a74df00-230d-45c6-b7d8-0f7f18b3ee95
# hash:0ed894da8e7026de11dfeaf666b1861fb3e81e1f0c9a7a342aae241ca41e03a9
# parent:None
# prev:node_id='cb0780c4-e5ad-48f1-8ca1-9a77401be37a' node_type=<ObjectType.TEXT: '1'> metadata={} hash='99ccdd7ff3e32ba648b69db8c20490e516a0ed6336c5d51fac3f4c0d5ab309f8'
# next:node_id='ab56a4ba-dedf-4c19-b3a4-205d4845f691' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'DATE OF INJURY': {0: 2010, 1: 2011, 2: 2012, 3: 2013, 4: 2014, 5: 2015, 6: 2016}, 'MINIMUM PAYMENTS': {0: '$148.00 per week', 1: '$148.00 per week', 2: '$151.57 per week', 3: '$160.00 per week', 4: '$161.19 per week', 5: '$165.49 per week', 6: '$169.26 per week'}, 'MAXIMUM PAYMENTS': {0: '$986.69 per week', 1: '$986.69 per week', 2: '$1,010.50 per week', 3: '$1,066.72 per week', 4: '$1,074.64 per week', 5: '$1,103.29 per week', 6: '$1,128.43 per week'}}", 'table_summary': 'Based on the given context information, I would summarize it as:\n\n**Table Title/Caption:** Weekly Payments for Injury Compensation\n\n**Summary:** This table provides a list of minimum and maximum weekly payments for injury compensation from 2010 to 2016.\n\n**Table ID:** Not provided\n\n**Should the table be kept?**: Yes, this table appears to provide important information for understanding payment amounts related to injuries over a period of time.,\nwith the following columns:\n'} hash='98dd6689cfd4e5a3bb3bb808dee488f00489c5383fe3abcf320a5181a5bac50f'
# next:node_id='ab56a4ba-dedf-4c19-b3a4-205d4845f691' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'DATE OF INJURY': {0: 2010, 1: 2011, 2: 2012, 3: 2013, 4: 2014, 5: 2015, 6: 2016}, 'MINIMUM PAYMENTS': {0: '$148.00 per week', 1: '$148.00 per week', 2: '$151.57 per week', 3: '$160.00 per week', 4: '$161.19 per week', 5: '$165.49 per week', 6: '$169.26 per week'}, 'MAXIMUM PAYMENTS': {0: '$986.69 per week', 1: '$986.69 per week', 2: '$1,010.50 per week', 3: '$1,066.72 per week', 4: '$1,074.64 per week', 5: '$1,103.29 per week', 6: '$1,128.43 per week'}}", 'table_summary': 'Based on the given context information, I would summarize it as:\n\n**Table Title/Caption:** Weekly Payments for Injury Compensation\n\n**Summary:** This table provides a list of minimum and maximum weekly payments for injury compensation from 2010 to 2016.\n\n**Table ID:** Not provided\n\n**Should the table be kept?**: Yes, this table appears to provide important information for understanding payment amounts related to injuries over a period of time.,\nwith the following columns:\n'} hash='98dd6689cfd4e5a3bb3bb808dee488f00489c5383fe3abcf320a5181a5bac50f'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the given context information, I would summarize it as:
#
# **Table Title/Caption:** Weekly Payments for Injury Compensation
#
# **Summary:** This table provides a list of minimum and maximum weekl
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:20093
# end_idx:20454
# =====================================
# id:15f91ccd-cef3-4817-b7cd-9271b8c0a391
# hash:62947616e33e4651d4c1fde2b56709a456bdc0dc1cd779c671c7db2152d9d72c
# parent:None
# prev:node_id='d29c68a0-02ee-4839-8f8f-a85621b39c49' node_type=<ObjectType.TEXT: '1'> metadata={} hash='6eb27acc1d9bb1ea460a75e558420e455315afdd6bda328e9f8876dd0b961c09'
# next:node_id='2df88aa5-f9a7-414b-ae9b-3f707b274563' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'DISABILITY': {0: 'Total loss of vision in one eye, normal vision in other eye', 1: 'Amputation of index finger at middle joint'}, 'INJURY IN 2005-12': {0: '$19,665.00 (total)', 1: '$6,210.00 (total)'}, 'INJURY IN 2013': {0: '$27,312.50 (total)', 1: '$7,877.50 (total)'}, 'INJURY IN 2014': {0: '$34,437.50 (total)', 1: '$9,932.50 (total)'}}", 'table_summary': 'Based on the provided context information, I would summarize the table as:\n\n**Table Title/Caption:** Cost of Living with Different Disabilities\n**Table ID:** N/A (since it was not provided)\n**Summary:** This table illustrates the total costs associated with living with various physical disabilities.\n\nThe table appears to be a summary of medical expenses or financial implications related to different injuries or conditions, such as vision loss and amputation. It provides a concise and comparable view of the costs involved for each disability over several years (2005-2014).\n\n**Table Keep:** Yes, this table should be kept as it presents valuable information on the financial aspects of living with disabilities, which can be useful for various purposes, such as planning, research, or advocacy.,\nwith the following columns:\n'} hash='843d917fea366f9653975256137d73c7f15b3d064a17eb31958a22fd2c8954cf'
# next:node_id='2df88aa5-f9a7-414b-ae9b-3f707b274563' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'DISABILITY': {0: 'Total loss of vision in one eye, normal vision in other eye', 1: 'Amputation of index finger at middle joint'}, 'INJURY IN 2005-12': {0: '$19,665.00 (total)', 1: '$6,210.00 (total)'}, 'INJURY IN 2013': {0: '$27,312.50 (total)', 1: '$7,877.50 (total)'}, 'INJURY IN 2014': {0: '$34,437.50 (total)', 1: '$9,932.50 (total)'}}", 'table_summary': 'Based on the provided context information, I would summarize the table as:\n\n**Table Title/Caption:** Cost of Living with Different Disabilities\n**Table ID:** N/A (since it was not provided)\n**Summary:** This table illustrates the total costs associated with living with various physical disabilities.\n\nThe table appears to be a summary of medical expenses or financial implications related to different injuries or conditions, such as vision loss and amputation. It provides a concise and comparable view of the costs involved for each disability over several years (2005-2014).\n\n**Table Keep:** Yes, this table should be kept as it presents valuable information on the financial aspects of living with disabilities, which can be useful for various purposes, such as planning, research, or advocacy.,\nwith the following columns:\n'} hash='843d917fea366f9653975256137d73c7f15b3d064a17eb31958a22fd2c8954cf'
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the provided context information, I would summarize the table as:
#
# **Table Title/Caption:** Cost of Living with Different Disabilities
# **Table ID:** N/A (since it was not provided)
# **Summary:
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:20756
# end_idx:21052
# =====================================
# id:c6bdce92-4d8a-4ef1-abb2-f977ba472b9f
# hash:32aa19ca9978f0bb78e3ede2a49694a206d15f7cf004f46c1c0f02d7a827d67c
# parent:None
# prev:node_id='1ee1e2b1-db58-465c-badc-4f84c02a0db9' node_type=<ObjectType.TEXT: '1'> metadata={} hash='cef02df03b9620490c6de1a0906d96e9a2ab8d6463af401597a96943d85b5e04'
# next:node_id='775b8d0e-e7d5-4da6-bc76-e52c352e7b8a' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'DATE OF INJURY': {0: '2004–12', 1: '2013 or later'}, 'MAXIMUM BENEFIT': {0: '$4,000 to $10,000, depending on permanent disability rating', 1: '$6,000'}}", 'table_summary': "**Caption:** California Workers' Compensation Benefits\n\n**Summary:** Maximum benefits for permanent disability ratings in California workers' compensation claims.\n\n**Table Title/Caption (as provided):** DATE OF INJURY|MAXIMUM BENEFIT|\n\n**Table ID (not provided):** N/A\n\n**Should the table be kept?:** Yes, it appears to provide important information about workers' compensation benefits and should be preserved for reference.,\nwith the following columns:\n"} hash='002d1da1865f627d00f3114275e33474d4fd6279249eb7fdacf011549549d081'
# next:node_id='775b8d0e-e7d5-4da6-bc76-e52c352e7b8a' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'DATE OF INJURY': {0: '2004–12', 1: '2013 or later'}, 'MAXIMUM BENEFIT': {0: '$4,000 to $10,000, depending on permanent disability rating', 1: '$6,000'}}", 'table_summary': "**Caption:** California Workers' Compensation Benefits\n\n**Summary:** Maximum benefits for permanent disability ratings in California workers' compensation claims.\n\n**Table Title/Caption (as provided):** DATE OF INJURY|MAXIMUM BENEFIT|\n\n**Table ID (not provided):** N/A\n\n**Should the table be kept?:** Yes, it appears to provide important information about workers' compensation benefits and should be preserved for reference.,\nwith the following columns:\n"} hash='002d1da1865f627d00f3114275e33474d4fd6279249eb7fdacf011549549d081'
# type:ObjectType.INDEX
# class:IndexNode
# content:**Caption:** California Workers' Compensation Benefits
#
# **Summary:** Maximum benefits for permanent disability ratings in California workers' compensation claims.
#
# **Table Title/Caption (as provided):
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:21096
# end_idx:21231
# =====================================
# id:af01cdc0-fef8-4546-b3e5-b06efd19df81
# hash:bf759791f1f52add2dd3c247c30378e78269c27c5a6f06d8cbe64334b95fa6c1
# parent:None
# prev:node_id='508e583c-3c57-4652-8682-fae3ab2df0ed' node_type=<ObjectType.TEXT: '1'> metadata={} hash='70508b7881a1ec0762bcf3dde6f41e8e7193b484652464133da366beee248cd8'
# next:node_id='9b8bc924-2b8e-4776-b8ad-6b83bd04f672' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'1. Send a letter to the claims administrator stating that you disagree with the medical report.': {0: ' '}, 'If you do not have an attorney, in some cases you must send the letter within 30 days after you received the report.': {0: 'If you have an attorney, in some cases your attorney must send the letter within 20 days after receiving the report.'}}", 'table_summary': "**Summary:** Timeframe for disputing medical reports in workers' compensation claims.\n\n**Table Title/Caption:** None provided\n\n**Table ID:** None provided\n\n**Keep Table?:** Yes, this table provides important information regarding the time-sensitive nature of disputing medical reports in workers' compensation claims.,\nwith the following columns:\n"} hash='64eee22815f3832bd08d4d19c8de39a7748aedb759ba84b222e042e7a7ea6a21'
# ...
# next:node_id='ff4f6bc7-4962-4ea9-b021-c3fe94301e0f' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Description of Employee’s Job Duties (DWC AD form 10133.33)': {0: 'Disability rater', 1: 'Disability rating', 2: 'Dispute', 3: 'Division of Workers’ Compensation (DWC)', 4: 'Fair Employment and Housing Act (FEHA)', 5: 'Family and Medical Leave Act (FMLA)', 6: 'Filing', 7: 'Findings and Award', 8: 'Health care organization (HCO)', 9: 'Hearing', 10: 'Independent Medical Review (IMR)'}, 'A form that is filled out jointly by the injured worker and the employer or claims administrator to help the treating physician determine whether the worker is able to return to his or her usual job and working conditions. The information on the form also helps the physician specify appropriate work restrictions.': {0: 'An employee of the Division of Workers’ Compensation who rates an injured worker’s permanent disability after reviewing a medical report or a medical-legal report that describes the worker’s condition. Also called “disability evaluator.”', 1: 'See “permanent disability rating.”', 2: 'A disagreement about a worker’s right to receive payments, services, or other benefits.', 3: 'A state agency that administers workers’ compensation laws, adjudicates disputes, and provides information and assistance to injured workers and others about the California workers’ compensation system.', 4: 'A state law, administered by the California Department of Fair Employment and Housing, that prohibits discrimination against disabled persons. Its provisions are more extensive in some areas than the federal Americans with Disabilities Act (ADA).', 5: 'A federal law, administered by the US Department of Labor, that requires most employers of 50 or more employees to grant job-protected leave to workers with serious health problems or who need to care for a child or other family member.', 6: 'Sending or delivering a document to an employer or a governmental agency as part of a legal process. The date of filing is the date the document is received.', 7: 'A written decision by a workers’ compensation administrative law judge about an injured worker’s case, including payments and future medical care that must be provided to the worker.', 8: 'An organization certified by the Division of Workers’ Compensation that contracts with an employer or insurer to provide managed medical care in the California workers’ compensation system.', 9: 'A legal proceeding or event where a workers’ compensation administrative law judge holds a meeting to discuss issues or receives information from different persons in order to make a decision about a dispute or a proposed settlement.', 10: 'This term refers to two different processes: • Independent review of a decision, communicated by a claims administrator, to deny or modify treatment recommended by a treating physician. An injured worker may request this type of IMR if the worker’s date of injury is on or after January 1, 2013, or the claims administrator communicated the decision to deny treatment on or after July 1, 2013. • Independent review of a treatment decision made by a treating physician in a medical provider network (MPN). An injured worker may request this type of IMR if the worker is being treated in an MPN and has obtained opinions from two other physicians in the MPN.'}}", 'table_summary': "Summary: This table provides definitions and descriptions of various terms related to California's workers' compensation system.\n\nTable Title/Caption: Description of Employee’s Job Duties (DWC AD form 10133.33)\n\nTable ID: DWC-AD-form-10133-33\n\nShould the table be kept? Yes, it should be kept as it provides important context and definitions for understanding various terms in California's workers' compensation system.,\nwith the following columns:\n"} hash='474f7fbab4770fe318c2973bedfa57ac11675b8fd320d26bb3833ee4dc440428'
# type:ObjectType.INDEX
# class:IndexNode
# content:Summary: This table provides definitions and descriptions of various terms related to California's workers' compensation system.
#
# Table Title/Caption: Description of Employee’s Job Duties (DWC AD form
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:144182
# end_idx:147316
# =====================================
# id:cf172b26-a6e4-4ada-9b72-b3af6f7c0410
# hash:3a396b19f538f6a3a841b3c5ff9041146aaa27364bb49ac3b65fd69dbf2f288b
# parent:None
# prev:node_id='a9bec5c3-ce44-42cf-aa2d-93a281c27f29' node_type=<ObjectType.TEXT: '1'> metadata={} hash='ec5d2f1a24bf5231858acbb3ea0dc7f4f28b588510e327df213b1b8bd730f36d'
# next:node_id='46b0dd1e-98c7-4fc0-a7ea-63ab977c59fd' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Predesignation.': {0: 'Primary treating physician (PTP).', 1: 'Qualified medical evaluator (QME).', 2: 'Rating.', 3: 'Reconsideration.', 4: 'Reconsideration of a summary rating.', 5: 'Regular work.', 6: 'Restrictions.', 7: 'Return-to-work supplement.', 8: 'Schedule for Rating Permanent Disabilities.', 9: 'Settlement.', 10: 'Social Security Disability Insurance (SSDI) and Supplemental Security Income (SSI) benefits.', 11: 'Specific injury.'}, 'A worker telling his or her employer in writing, before getting hurt on the job, the name and address of the worker’s personal physician in case of job injury. This physician must be the worker’s primary care physician and must agree to be predesignated. A worker may also predesignate a medical group. If a worker predesignates, he or she will be allowed to be treated by the personal physician right after injury instead of a physician selected by the employer or the claims administrator. Workers can predesignate only if, on the date of injury, the worker has health care coverage for medical conditions that are unrelated to work. See also “personal physician.”': {0: 'The doctor who is responsible for managing the overall care of the injured worker and who writes medical reports that may affect the worker’s benefits.', 1: 'A doctor who is selected by either an injured worker, an injured worker’s attorney, or a claims administrator, from a list provided by the Division of Workers’ Compensation, to conduct a medical examination and prepare a medical-legal report to help resolve a dispute. QMEs are certified by the Division of Workers’ Compensation.', 2: 'See “permanent disability rating.”', 3: 'A legal process for appealing a decision made by a workers’ compensation administrative law judge.', 4: 'A process for determining whether mistakes were made in determining the permanent disability rating of an injured worker who does not have an attorney.', 5: 'An injured worker’s old job, paying the same wages and benefits as paid at the time of injury and located within a reasonable commuting distance of where the worker lived at the time of injury.', 6: 'See “work restrictions.”', 7: 'A supplemental benefit for injured workers, injured in 2013 or later, who have received a supplemental job displacement benefit (SJDB) voucher and who experience a disproportionate loss of earnings.', 8: 'A state publication containing detailed information that is used to rate permanent disabilities. There are three schedules. See Chapter 7.', 9: 'An agreement between an injured worker and the claims administrator about the workers’ compensation payments and future medical care that will be provided to the worker. Settlements must be reviewed by a workers’ compensation administrative law judge to determine whether they are adequate to compensate the injured worker for the injury.', 10: 'Financial assistance for disabled persons. These benefits are administered by the US Social Security Administration. They may be reduced by workers’ compensation payments that the injured worker receives.', 11: 'An injury that was caused by one event at work. Examples: hurting one’s back in a fall, getting burned by a chemical that splashes on the skin, getting hurt in a car accident while making deliveries.'}}", 'table_summary': "Based on the context information, I would summarize this table as:\n\n**Table Summary:** This table appears to provide definitions and explanations of various terms related to workers' compensation insurance.\n\n**Table Title/Caption:** Predesignation | Primary Treating Physician (PTP) | Qualified Medical Evaluator (QME) | Rating | Reconsideration | Reconsideration of a summary rating | Regular work | Restrictions | Return-to-work supplement | Schedule for Rating Permanent Disabilities | Settlement | Social Security Disability Insurance (SSDI) and Supplemental Security Income (SSI) benefits | Specific  ...
# next:node_id='46b0dd1e-98c7-4fc0-a7ea-63ab977c59fd' node_type=<ObjectType.TEXT: '1'> metadata={'table_df': "{'Predesignation.': {0: 'Primary treating physician (PTP).', 1: 'Qualified medical evaluator (QME).', 2: 'Rating.', 3: 'Reconsideration.', 4: 'Reconsideration of a summary rating.', 5: 'Regular work.', 6: 'Restrictions.', 7: 'Return-to-work supplement.', 8: 'Schedule for Rating Permanent Disabilities.', 9: 'Settlement.', 10: 'Social Security Disability Insurance (SSDI) and Supplemental Security Income (SSI) benefits.', 11: 'Specific injury.'}, 'A worker telling his or her employer in writing, before getting hurt on the job, the name and address of the worker’s personal physician in case of job injury. This physician must be the worker’s primary care physician and must agree to be predesignated. A worker may also predesignate a medical group. If a worker predesignates, he or she will be allowed to be treated by the personal physician right after injury instead of a physician selected by the employer or the claims administrator. Workers can predesignate only if, on the date of injury, the worker has health care coverage for medical conditions that are unrelated to work. See also “personal physician.”': {0: 'The doctor who is responsible for managing the overall care of the injured worker and who writes medical reports that may affect the worker’s benefits.', 1: 'A doctor who is selected by either an injured worker, an injured worker’s attorney, or a claims administrator, from a list provided by the Division of Workers’ Compensation, to conduct a medical examination and prepare a medical-legal report to help resolve a dispute. QMEs are certified by the Division of Workers’ Compensation.', 2: 'See “permanent disability rating.”', 3: 'A legal process for appealing a decision made by a workers’ compensation administrative law judge.', 4: 'A process for determining whether mistakes were made in determining the permanent disability rating of an injured worker who does not have an attorney.', 5: 'An injured worker’s old job, paying the same wages and benefits as paid at the time of injury and located within a reasonable commuting distance of where the worker lived at the time of injury.', 6: 'See “work restrictions.”', 7: 'A supplemental benefit for injured workers, injured in 2013 or later, who have received a supplemental job displacement benefit (SJDB) voucher and who experience a disproportionate loss of earnings.', 8: 'A state publication containing detailed information that is used to rate permanent disabilities. There are three schedules. See Chapter 7.', 9: 'An agreement between an injured worker and the claims administrator about the workers’ compensation payments and future medical care that will be provided to the worker. Settlements must be reviewed by a workers’ compensation administrative law judge to determine whether they are adequate to compensate the injured worker for the injury.', 10: 'Financial assistance for disabled persons. These benefits are administered by the US Social Security Administration. They may be reduced by workers’ compensation payments that the injured worker receives.', 11: 'An injury that was caused by one event at work. Examples: hurting one’s back in a fall, getting burned by a chemical that splashes on the skin, getting hurt in a car accident while making deliveries.'}}", 'table_summary': "Based on the context information, I would summarize this table as:\n\n**Table Summary:** This table appears to provide definitions and explanations of various terms related to workers' compensation insurance.\n\n**Table Title/Caption:** Predesignation | Primary Treating Physician (PTP) | Qualified Medical Evaluator (QME) | Rating | Reconsideration | Reconsideration of a summary rating | Regular work | Restrictions | Return-to-work supplement | Schedule for Rating Permanent Disabilities | Settlement | Social Security Disability Insurance (SSDI) and Supplemental Security Income (SSI) benefits | Specific  ...
# type:ObjectType.INDEX
# class:IndexNode
# content:Based on the context information, I would summarize this table as:
#
# **Table Summary:** This table appears to provide definitions and explanations of various terms related to workers' compensation insu
# metadata:{'col_schema': ''}
# extra:{'col_schema': ''}
# start_idx:154505
# end_idx:157644
# =====================================

# %%
from neo4j import GraphDatabase

# Local Neo4j instance
# NEO4J_URL = "bolt://localhost:7687"
# Remote Neo4j instance on AuraDB
NEO4J_URL = "bolt://neo4j-1:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "abc123abc123"
NEO4J_DATABASE = ""

def initialiseNeo4jSchema():
    cypher_schema = [
        "CREATE CONSTRAINT sectionKey IF NOT EXISTS FOR (c:Section) REQUIRE (c.key) IS UNIQUE;",
        "CREATE CONSTRAINT chunkKey IF NOT EXISTS FOR (c:Chunk) REQUIRE (c.key) IS UNIQUE;",
        "CREATE CONSTRAINT documentKey IF NOT EXISTS FOR (c:Document) REQUIRE (c.url_hash) IS UNIQUE;",
        "CREATE VECTOR INDEX `chunkVectorIndex` IF NOT EXISTS FOR (e:Embedding) ON (e.value) OPTIONS { indexConfig: {`vector.dimensions`: 1536, `vector.similarity_function`: 'cosine'}};"
    ]

    driver = GraphDatabase.driver(NEO4J_URL, database=NEO4J_DATABASE, auth=(NEO4J_USER, NEO4J_PASSWORD))

    with driver.session() as session:
        for cypher in cypher_schema:
            session.run(cypher)
    driver.close()

# %%
initialiseNeo4jSchema()

# %%
driver = GraphDatabase.driver(NEO4J_URL, database=NEO4J_DATABASE, auth=(NEO4J_USER, NEO4J_PASSWORD))

# ================================================
# 1) Save documents

print("Start saving documents to Neo4j...")
i = 0
with driver.session() as session:
    for doc in documents:
        cypher = "MERGE (d:Document {url_hash: $doc_id}) ON CREATE SET d.url=$url;"
        session.run(cypher, doc_id=doc.doc_id, url=doc.doc_id)
        i = i + 1
    session.close()

print(f"{i} documents saved.")

# ================================================
# 2) Save nodes

print("Start saving nodes to Neo4j...")

i = 0
with driver.session() as session:
    for node in base_nodes: 

        # >>1 Create Section node
        cypher  = "MERGE (c:Section {key: $node_id})\n"
        cypher += " FOREACH (ignoreMe IN CASE WHEN c.type IS NULL THEN [1] ELSE [] END |\n"
        cypher += "     SET c.hash = $hash, c.text=$content, c.type=$type, c.class=$class_name, c.start_idx=$start_idx, c.end_idx=$end_idx )\n"
        cypher += " WITH c\n"
        cypher += " MATCH (d:Document {url_hash: $doc_id})\n"
        cypher += " MERGE (d)<-[:HAS_DOCUMENT]-(c);"

        node_json = json.loads(node.json())

        session.run(cypher, node_id=node.node_id, hash=node.hash, content=node.get_content(), type='TEXT', class_name=node.class_name()
                          , start_idx=node_json['start_char_idx'], end_idx=node_json['end_char_idx'], doc_id=node.ref_doc_id)

        # >>2 Link node using NEXT relationship

        if node.next_node is not None: # and node.next_node.node_id[-1*len(TABLE_REF_SUFFIX):] != TABLE_REF_SUFFIX:
            cypher  = "MATCH (c:Section {key: $node_id})\n"    # current node should exist
            cypher += "MERGE (p:Section {key: $next_id})\n"    # previous node may not exist
            cypher += "MERGE (p)<-[:NEXT]-(c);"

            session.run(cypher, node_id=node.node_id, next_id=node.next_node.node_id)

        if node.prev_node is not None:  # Because tables are in objects list, so we need to link from the opposite direction
            cypher  = "MATCH (c:Section {key: $node_id})\n"    # current node should exist
            cypher += "MERGE (p:Section {key: $prev_id})\n"    # previous node may not exist
            cypher += "MERGE (p)-[:NEXT]->(c);"

            if node.prev_node.node_id[-1 * len(TABLE_ID_SUFFIX):] == TABLE_ID_SUFFIX:
                prev_id = node.prev_node.node_id + '_ref'
            else:
                prev_id = node.prev_node.node_id

            session.run(cypher, node_id=node.node_id, prev_id=prev_id)

        i = i + 1
    session.close()

print(f"{i} nodes saved.")

# ================================================
# 3) Save objects

print("Start saving objects to Neo4j...")

i = 0
with driver.session() as session:
    for node in objects:               
        node_json = json.loads(node.json())

        # Object is a Table, then the ????_ref_table object is created as a Section, and the table object is Chunk
        if node.node_id[-1 * len(TABLE_REF_SUFFIX):] == TABLE_REF_SUFFIX:
            if node.next_node is not None:  # here is where actual table object is loaded
                next_node = node.next_node

                obj_metadata = json.loads(str(next_node.json()))

                cypher  = "MERGE (s:Section {key: $node_id})\n"
                cypher += "WITH s MERGE (c:Chunk {key: $table_id})\n"
                cypher += " FOREACH (ignoreMe IN CASE WHEN c.type IS NULL THEN [1] ELSE [] END |\n"
                cypher += "     SET c.hash = $hash, c.definition=$content, c.text=$table_summary, c.type=$type, c.start_idx=$start_idx, c.end_idx=$end_idx )\n"
                cypher += " WITH s, c\n"
                cypher += " MERGE (s) <-[:UNDER_SECTION]- (c)\n"
                cypher += " WITH s MATCH (d:Document {url_hash: $doc_id})\n"
                cypher += " MERGE (d)<-[:HAS_DOCUMENT]-(s);"

                session.run(cypher, node_id=node.node_id, hash=next_node.hash, content=obj_metadata['metadata']['table_df'], type='TABLE'
                                  , start_idx=node_json['start_char_idx'], end_idx=node_json['end_char_idx']
                                  , doc_id=node.ref_doc_id, table_summary=obj_metadata['metadata']['table_summary'], table_id=next_node.node_id)
                
            if node.prev_node is not None:
                cypher  = "MATCH (c:Section {key: $node_id})\n"    # current node should exist
                cypher += "MERGE (p:Section {key: $prev_id})\n"    # previous node may not exist
                cypher += "MERGE (p)-[:NEXT]->(c);"

                if node.prev_node.node_id[-1 * len(TABLE_ID_SUFFIX):] == TABLE_ID_SUFFIX:
                    prev_id = node.prev_node.node_id + '_ref'
                else:
                    prev_id = node.prev_node.node_id
                
                session.run(cypher, node_id=node.node_id, prev_id=prev_id)
                
        i = i + 1
    session.close()

# ================================================
# 4) Create Chunks for each Section object of type TEXT
# If there are changes to the content of TEXT section, the Section node needs to be recreated

print("Start creating chunks for each TEXT Section...")

with driver.session() as session:

    cypher  = "MATCH (s:Section) WHERE s.type='TEXT' \n"
    cypher += "WITH s CALL {\n"
    cypher += "WITH s WITH s, split(s.text, '\n') AS para\n"
    cypher += "WITH s, para, range(0, size(para)-1) AS iterator\n"
    cypher += "UNWIND iterator AS i WITH s, trim(para[i]) AS chunk, i WHERE size(chunk) > 0\n"
    cypher += "CREATE (c:Chunk {key: s.key + '_' + i}) SET c.type='TEXT', c.text = chunk, c.seq = i \n"
    cypher += "CREATE (s) <-[:UNDER_SECTION]-(c) } IN TRANSACTIONS OF 500 ROWS ;"
    
    session.run(cypher)
    
    session.close()


print(f"{i} objects saved.")

print("=================DONE====================")

driver.close()
# Out:
# Start saving documents to Neo4j...
# 1 documents saved.
# Start saving nodes to Neo4j...
# 60 nodes saved.
# Start saving objects to Neo4j...
# Start creating chunks for each TEXT Section...
# 42 objects saved.
# =================DONE====================

# %% [markdown]
# # Generating and Storing Text Embeddings

# %%
import ollama
from ollama import Client
client = Client(host='http://192.168.1.102:11434')
client.embeddings(model='llama3', prompt='The sky is blue because of rayleigh scattering')
# Out:
# {'embedding': [-3.616058588027954,
#   0.26187846064567566,
#   0.28789177536964417,
#   -0.3928515613079071,
#   1.602487564086914,
#   -1.2847929000854492,
#   -0.28260573744773865,
#   -0.5155466198921204,
#   -2.4808707237243652,
#   1.3253742456436157,
#   1.7212176322937012,
#   -0.9524745345115662,
#   -0.7613602876663208,
#   2.6409990787506104,
#   0.2827461361885071,
#   0.5220630764961243,
#   -1.3409188985824585,
#   2.080493450164795,
#   -4.873706340789795,
#   0.9225631356239319,
#   -4.767677307128906,
#   0.018306050449609756,
#   0.9042076468467712,
#   1.4699585437774658,
#   -0.6879159212112427,
#   0.99538254737854,
#   5.167906761169434,
#   0.7671281099319458,
#   2.490455150604248,
#   -1.202128529548645,
#   -0.8251153826713562,
#   1.0738463401794434,
#   -0.9881787300109863,
#   1.4650189876556396,
#   4.136751651763916,
#   -1.4955487251281738,
#   -1.879084825515747,
#   -2.689141035079956,
#   1.9198271036148071,
#   4.672626972198486,
#   -0.05280758813023567,
#   -1.6274168491363525,
#   0.750299870967865,
#   -0.833224892616272,
#   2.4057796001434326,
#   1.3162492513656616,
#   1.019997000694275,
#   0.9182478785514832,
#   -1.1039577722549438,
#   9.52568531036377,
#   1.766196846961975,
#   2.1078481674194336,
#   0.9340718984603882,
#   1.0945461988449097,
#   -0.45168548822402954,
#   1.424911618232727,
#   1.8322181701660156,
#   2.288529872894287,
#   0.9509982466697693,
#   1.607391119003296,
#   0.9862353801727295,
#   2.3953208923339844,
#   -0.24248579144477844,
#   -4.792343616485596,
#   3.2064363956451416,
#   3.6375346183776855,
#   -2.092956781387329,
#   2.4640395641326904,
#   -4.6394782066345215,
#   -2.4072141647338867,
#   3.4843878746032715,
#   2.049309015274048,
#   0.7044890522956848,
#   -2.4374377727508545,
#   -3.2615883350372314,
#   0.175246924161911,
#   1.7259302139282227,
#   -0.06114223599433899,
#   -0.1737924963235855,
#   -1.8609198331832886,
#   -0.6687532067298889,
#   1.838834285736084,
#   1.4373153448104858,
#   2.6334640979766846,
#   -2.9016060829162598,
#   -1.9962655305862427,
#   -3.914108991622925,
#   -0.6800351738929749,
#   0.8610196113586426,
#   -0.4010084271430969,
#   -1.3504620790481567,
#   -0.21681828796863556,
#   0.9156560897827148,
#   -0.040559470653533936,
#   -2.2822439670562744,
#   -1.3098927736282349,
#   -4.944243431091309,
#   1.9078718423843384,
#   1.555039882659912,
#   1.8824279308319092,
#   1.4837894439697266,
#   -1.1837626695632935,
#   1.3534525632858276,
#   -1.985977292060852,
#   0.9872627854347229,
#   -2.5279250144958496,
#   -0.45189741253852844,
#   -1.5312250852584839,
#   -0.499357134103775,
#   ...]}

# %%
from openai import OpenAI
import ollama

EMBEDDING_MODEL = "nomic-embed-text"

def get_embedding(client, text, model):
    response = client.embeddings(
                    prompt=text,
                    model=model,
                )
    return response["embedding"]

def LoadEmbedding(label, property):
    driver = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USER, NEO4J_PASSWORD), database=NEO4J_DATABASE)
    client = Client(host='http://192.168.1.102:11434')
    
    with driver.session() as session:
        # get chunks in document, together with their section titles
        result = session.run(f"MATCH (ch:{label}) RETURN id(ch) AS id, ch.{property} AS text")
        # call OpenAI embedding API to generate embeddings for each proporty of node
        # for each node, update the embedding property
        count = 0
        for record in result:
            id = record["id"]
            text = record["text"]
            
            # For better performance, text can be batched
            embedding = get_embedding(client, text, EMBEDDING_MODEL)
            
            # key property of Embedding node differentiates different embeddings
            cypher = "CREATE (e:Embedding) SET e.key=$key, e.value=$embedding, e.model=$model"
            cypher = cypher + " WITH e MATCH (n) WHERE id(n) = $id CREATE (n) -[:HAS_EMBEDDING]-> (e)"
            session.run(cypher,key=property, embedding=embedding, id=id, model=EMBEDDING_MODEL) 
            count = count + 1

        session.close()
        
        print("Processed " + str(count) + " " + label + " nodes for property @" + property + ".")
        return count

# %%
# For smaller amount (<2000) of text data to embed
LoadEmbedding("Chunk", "text")
# Out:
# Processed 1043 Chunk nodes for property @text.
# 1043
