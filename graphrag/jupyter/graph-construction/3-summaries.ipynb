# %% [markdown]
# # Expand With Summary
#
# The Chunk Nodes are individual chunks of text that used
# to be part of an entire document.
#
# You can reconstruct the original context by connecting the nodes
# with relationships. It also makes the data easy to navigate and understand.
#
# That is super helpful when you're building an application, for debugging and testing.
#
# And, you can provide a better user experience. Your users will be able
# to directly interact with the data and even provide feedback that will
# improve subsequent answers.
#
# You will create a connected context by making the following
# changes to the knowledge graph:
#
# 1. Extract, create `(:Document)` nodes for each original source Form.
# 2. Enhance, add a summarized text property to each `(:Form)` node.
# 3. Expand, connect each `(:Chunk)` to the `(:Form)` node that it is part of
#
# The graph will look like this...
#
# ```cypher
# (:Section
#   sectionId: string //  a unique identifier for the form
#   documentUri: string
#   summary: string // text summary generated with the LLM
#   summaryEmbedding: float[] // vector embedding of summary
# )
# ```
#
# ```cypher
# // Document contains sections
# (:Document)-[:CONTAINS]->(:Section)
#
# // Section contains Chunks
# (:Section)-[:CONTAINS]->(:Chunk)
# ```

# %% [markdown]
# ## Setup

# %%
# %run 'shared.ipynb'
# Out:
# #*****************************************************************
# # Neo4j
# #*****************************************************************
# NEO4J_URI=bolt://neo4j-1:7687
# NEO4J_USERNAME=neo4j
# NEO4J_PASSWORD=abc123abc123
# NEO4J_DATABASE=neo4j
#
# # either ollama or openai
# EMBEDDING_API=ollama
# EMBEDDING_MODEL=mxbai-embed-large
# # either ollama or openai
# CHAT_API=ollama
# CHAT_MODEL=llama3
#
# #OLLAMA_URL=http://192.168.1.102:11434
# #OLLAMA_URL=http://172.20.10.2:11434
# OLLAMA_URL=http://host.docker.internal:11434
# OPEN_API_KEY=
#
# DATA_DIR=
#
# Connecting to Neo4j at bolt://neo4j-1:7687 as neo4j
# Embedding with ollama using mxbai-embed-large
# Chatting with ollama using llama3

# %% [markdown]
# # Enhance - create summary property, with embedding
#
# During the file processing above, the text from all interesting
# items were added to the `fullText` property of the `all_forms` dictionaries.
#
# We'll use an LLM to summarize the text and create an embedding.
#
# Both the text summary and the embdding will be added to the Section nodes.

# %%
# Create an embedding to find out the dimensions of the vector
text_embedding = embeddings_api.embed_query("embed this text using an LLM")
vector_dimensions = len(text_embedding) 

print(f"Text embeddings will have {vector_dimensions} dimensions")
# Create a vector index called "sections_vector" the `summaryEmbedding`` property of nodes labeled `Section`. 
gdb.execute_query("""
         CREATE VECTOR INDEX `sections_vector` IF NOT EXISTS
          FOR (s:Section) ON (s.summaryEmbedding) 
          OPTIONS { indexConfig: {
            `vector.dimensions`: $vectorDimensionsParam,
            `vector.similarity_function`: 'cosine'    
         }}
""",
  vectorDimensionsParam=vector_dimensions
)

# Check the vector indexes in the graph
gdb.execute_query('SHOW VECTOR INDEXES').records
# Out:
# Text embeddings will have 1024 dimensions
# [<Record id=8 name='sections_vector' state='ONLINE' populationPercent=100.0 type='VECTOR' entityType='NODE' labelsOrTypes=['Section'] properties=['summaryEmbedding'] indexProvider='vector-2.0' owningConstraint=None lastRead=None readCount=None>]

# %%
# %%time

query = """
MATCH (s:Section)-[:CONTAINS]->(c:Chunk)
WHERE s.summary is null
WITH s, collect(c.text) as textList
RETURN s.sectionId AS sectionId
        , s.level AS level
        , apoc.text.join(textList, " \n ") AS text
"""

sections_with_text = gdb.execute_query(query).records
for section in sections_with_text[0:]:
    section_info = {}
    text = section["text"]
    result = chat_api.invoke(
      f"""Write a single, very brief sentence summary
       based on the following information...\n {text}. Do not respond with "Here is a brief sentence summary:" 
      """)
    summary = result.content
    print(f"Summarized {len(summary)} characters. Here's a preview...")
    print(f"\t{summary[:120]}")
    section_info['summary'] = summary
    section_info['sectionId'] = section["sectionId"]
    
    summary_embedding = embeddings_api.embed_query(summary)
    section_info['summaryEmbedding'] = summary_embedding
    print(f"\tUpdating section with ID {section_info['sectionId']} with summary and embedding...")
    gdb.execute_query("""
      MATCH (s:Section {sectionId: $sectionInfoParam.sectionId})
        SET s.summary = $sectionInfoParam.summary 
      WITH s
        CALL db.create.setNodeVectorProperty(s, "summaryEmbedding", $sectionInfoParam.summaryEmbedding)    
    """, 
    sectionInfoParam=section_info
    )
# Out:
# Summarized 205 characters. Here's a preview...
# 	The IIHF Championship program aims to provide a standardized set of rules for ice hockey, ensuring a fair and leveled st
# 	Updating section with ID ca4f9dcf204e2037bfe5884867bead98bd9cbaf8 with summary and embedding...
# Summarized 144 characters. Here's a preview...
# 	The IIHF governs games played on rinks that adhere to specific dimensions and specifications, with limited exceptions fo
# 	Updating section with ID 70669d65799f0b85f53fa4d87f745b1ec129af58 with summary and embedding...
# Summarized 155 characters. Here's a preview...
# 	The official size of an ice rink used in IIHF competitions is 60m long and 26-30m wide, with rounded corners formed by a
# 	Updating section with ID 3256ff621b0e47207f42b2db33a4589ec1ddd458 with summary and embedding...
# Summarized 211 characters. Here's a preview...
# 	The protective glass and boards surrounding an ice rink must meet specific height and construction requirements to ensur
# 	Updating section with ID b9ea9b87e07555afd018b9a39b5c3e4180414475 with summary and embedding...
# Summarized 175 characters. Here's a preview...
# 	Protective netting must be installed in the ends of the arena to protect spectators from pucks and players, meeting IIHF
# 	Updating section with ID c31a58e8aebfd957ed100bf860f367a0ca7c37de with summary and embedding...
# Summarized 188 characters. Here's a preview...
# 	The ice surface is divided into three zones by blue lines and has center and goal lines, including a goal crease in fron
# 	Updating section with ID 33bbd5d4396f7a37424294fafc0121f191315280 with summary and embedding...
# Summarized 256 characters. Here's a preview...
# 	The ice surface can be divided into three zones: the Defending Zone, where the defending team's goal is located; the Neu
# 	Updating section with ID e8ebe4b66543c09f5bac45ba3fdafd0bd5cfd9ee with summary and embedding...
# Summarized 171 characters. Here's a preview...
# 	The On-ice Officials Crease is a semi-circular area marked on the ice surface, 3.0 meters in radius, used by official sc
# 	Updating section with ID 6bf9aa52a71387b24f7bbcb37508abac4bdecd88 with summary and embedding...
# Summarized 134 characters. Here's a preview...
# 	The Goalkeeper Restricted Area is marked by two red lines, 5 cm wide, that form a trapezoid shape behind each goal on th
# 	Updating section with ID 00bdc8a9dadfd2e48a88151e81d444ba819b6c81 with summary and embedding...
# Summarized 150 characters. Here's a preview...
# 	Face-off spots and circles are marked on the ice, including at center ice, in end zones, and in the neutral zone, with s
# 	Updating section with ID 67497a5eae5707da3d9ddcb2f119c8e8cea1ef2a with summary and embedding...
# Summarized 128 characters. Here's a preview...
# 	The arena staff performs regular ice resurfacing during intermissions and may also conduct additional snow removal if ne
# 	Updating section with ID dca3be45c57d63fcc381f72165dc3bdda17e4d3c with summary and embedding...
# Summarized 176 characters. Here's a preview...
# 	Goal posts and nets are designed to stand 1.22m tall, 1.83m apart, with red frames and white exteriors, and are anchored
# 	Updating section with ID f646b141d0991192ac1d28d9fe61c3c1646e1003 with summary and embedding...
# Summarized 199 characters. Here's a preview...
# 	The hockey goal's padding and netting must be designed to prevent pucks from resting outside the net while keeping them
# 	Updating section with ID f3089a543e1885c5dd82b8fcc398c83d8fecbc88 with summary and embedding...
# Summarized 201 characters. Here's a preview...
# 	The Players' Benches are placed on one side of the rink, near the center, and are separated from spectators by protectiv
# 	Updating section with ID b4c693d986445ccb7638cac8d8f4e878c305cc9b with summary and embedding...
# Summarized 173 characters. Here's a preview...
# 	The Penalty Boxes are identical, single-door compartments on opposite sides of the rink, accessible only to the Penalty
# 	Updating section with ID 198cbf9ca65be77eefe1648dafbb98914328c95d with summary and embedding...
# Summarized 160 characters. Here's a preview...
# 	A sound device must be provided for each rink and will automatically signal the end of each period; if it fails, the gam
# 	Updating section with ID 9ff4f0cd36af95bd1e2468965f74838817964ed6 with summary and embedding...
# Summarized 150 characters. Here's a preview...
# 	The Game Time Clock measures time remaining in tenths of a second during the last minute of each period, displaying time
# 	Updating section with ID 539e275ae9b1981af688398470715b50b3a818e9 with summary and embedding...
# Summarized 193 characters. Here's a preview...
# 	The Coach must submit the Line-up/Roster Sheet to the Official Scorekeeper at least 60 minutes prior to game time, listi
# 	Updating section with ID cfe9c613d83be29f23f90c248f91e577580dcd3d with summary and embedding...
# Summarized 125 characters. Here's a preview...
# 	A goal scored when an ineligible player is on the ice will be disallowed, while all previous goals by that team remain v
# 	Updating section with ID b503b082729ab3c218f2c75a688e01932ce84521 with summary and embedding...
# Summarized 192 characters. Here's a preview...
# 	In ice hockey, each team has two goalkeepers listed on the official game sheet, but can have a third goalkeeper who can
# 	Updating section with ID e48009019c529b6cd22c22b83fc52e1e9a45a2ef with summary and embedding...
# Summarized 200 characters. Here's a preview...
# 	Only registered players and team personnel can occupy the player benches, with each team required to have at least one s
# 	Updating section with ID 8e5f4fcb71104ba65aab782217907ceeba8f5a30 with summary and embedding...
# Summarized 185 characters. Here's a preview...
# 	Team personnel on or near the Players' Bench can use radio technology to communicate with others in designated areas, wh
# 	Updating section with ID 76b13896989aa2665c23dc3fe44d2f4b64af9a85 with summary and embedding...
# Summarized 221 characters. Here's a preview...
# 	Players must wear proper protective equipment during warm-up on the ice and may only participate in pre-game warm-ups if
# 	Updating section with ID c1d63974cc975ac83dc3d57472ea8b6177a797c1 with summary and embedding...
# Summarized 238 characters. Here's a preview...
# 	The Captain, Alternate Captain, or any player who protests or intervenes with officials shall be assessed a minor penalt
# 	Updating section with ID a74837e404a15341f4404ac73158d0f08bde8085 with summary and embedding...
# Summarized 136 characters. Here's a preview...
# 	When the Captain is absent, the Alternate Captain assumes leadership duties and wears an "A" logo on their jersey to sig
# 	Updating section with ID baf56e9c3bea2058e4174bed8a301ea4ddfaf7d3 with summary and embedding...
# Summarized 202 characters. Here's a preview...
# 	In the event of an injury, play can be stopped immediately by the Referee and/or Linesperson, and injured players must b
# 	Updating section with ID 199a3743eeb171a0da80763b10c06e953b6e41e8 with summary and embedding...
# Summarized 202 characters. Here's a preview...
# 	When a goalkeeper sustains an injury or illness, they must be replaced immediately unless they need medical attention on
# 	Updating section with ID 5b6f4fb78f171fc5aa98aec22e71c75d06a5cb31 with summary and embedding...
# Summarized 227 characters. Here's a preview...
# 	A player who is bleeding or has visible blood on their equipment or body must leave the ice at the next stoppage of play
# 	Updating section with ID 198e540f3fb2da98e855c788d217c6a63cb53d2e with summary and embedding...
# Summarized 195 characters. Here's a preview...
# 	Players' jerseys must meet specific design and color requirements, including no alterations, uniform numbers, and no abu
# 	Updating section with ID 6f1d0bdfd1766d92565a682a27f165ef1b7c9543 with summary and embedding...
# Summarized 173 characters. Here's a preview...
# 	Players must wear an individual identifying number on the back and sleeves of their jersey, along with their surname in
# 	Updating section with ID a8566ddb6c9e5039e953b3d93d247e78313ae3e7 with summary and embedding...
# Summarized 163 characters. Here's a preview...
# 	Players who fail to comply with jersey rules, including length and modifications, risk being assessed a minor penalty or
# 	Updating section with ID c4f538e8af3cb07afa3ba3c3772c52ff3bd73516 with summary and embedding...
# Summarized 144 characters. Here's a preview...
# 	Goalkeepers must adhere to specific rules regarding their jerseys, including size, modifications, and tie-downs, to ensu
# 	Updating section with ID 57589822ae5a09b81ac03a4d1f62bd6801310636 with summary and embedding...
# Summarized 163 characters. Here's a preview...
# 	Protective equipment must meet safety standards and be worn correctly to prevent injury, with penalties assessed for non
# 	Updating section with ID 9fa52b1dcaab27ecf6dd116641cf169492605586 with summary and embedding...
# Summarized 171 characters. Here's a preview...
# 	Players must wear their helmets properly fastened at all times during gameplay, and any player who exits the penalty box
# 	Updating section with ID d3bffbdce2874d325e9ee7905167a98d7515b2b2 with summary and embedding...
# Summarized 175 characters. Here's a preview...
# 	In IIHF competitions, players must wear helmets with approved visors or face protection that cover eyes and nose, with s
# 	Updating section with ID 95b2759b78f8f67cdb5809d32382e1189b615382 with summary and embedding...
# Summarized 190 characters. Here's a preview...
# 	The use of dangerous equipment, including non-approved gear and modified sticks, can result in penalties, warnings, and
# 	Updating section with ID e0a02ea89d61d2b22766746f985ed3c4338c994c with summary and embedding...
# Summarized 139 characters. Here's a preview...
# 	Skaters' shin pads must conform to a specific size and design to fit within standard socks, with no modifications or pro
# 	Updating section with ID 69878f148574807e494f0601fc133d9359f9e796 with summary and embedding...
# Summarized 189 characters. Here's a preview...
# 	Skating equipment regulations require a minimalist approach, allowing only four parts (boot, blade, holder, and laces) w
# 	Updating section with ID aa7e1605d4e7f9dc051a1e4ebb8f36198c241483 with summary and embedding...
# Summarized 153 characters. Here's a preview...
# 	Goalkeepers' skates must have flat blades that do not exceed the length of the boot and cannot include any add-ons or mo
# 	Updating section with ID fc1dab8b7b2516d756cab3c1c233041d72444bd2 with summary and embedding...
# Summarized 157 characters. Here's a preview...
# 	Players are required to wear neck laceration protection covering a large area, with goalkeepers also using throat protec
# 	Updating section with ID 78937ac926942bafd245348eca5b0e8da8a99349 with summary and embedding...
# Summarized 233 characters. Here's a preview...
# 	Players who participate in senior categories but are under 20 or 18 must wear protective equipment specific to those age
# 	Updating section with ID 12458d9d1e988684f81ebc51cfe4cb74d807a07e with summary and embedding...
# Summarized 181 characters. Here's a preview...
# 	The International Ice Hockey Federation (IIHF) governs the dimensions and materials used in hockey sticks, including res
# 	Updating section with ID e7b78fb4aba09b3c5607ddb5761483022de14c8c with summary and embedding...
# Summarized 155 characters. Here's a preview...
# 	Goalkeepers' sticks must meet specific dimensions, including knob thickness, length, width, and curvature, to ensure saf
# 	Updating section with ID a3e78fdcd9c2b81af90957576d958dfb2dfb1e67 with summary and embedding...
# Summarized 193 characters. Here's a preview...
# 	A player's stick is considered broken if it's unfit for normal play and must be dropped; replacement sticks can be obtai
# 	Updating section with ID dd43b18f7a286ee9b70a44020638f0dd6ba81b82 with summary and embedding...
# Summarized 157 characters. Here's a preview...
# 	A goalkeeper can continue playing with a broken stick until it's replaced or play stops, and teammates can pass them a n
# 	Updating section with ID efee91dda27f774cacec45c20281080ddd743534 with summary and embedding...
# Summarized 261 characters. Here's a preview...
# 	The rules governing stick measurements in hockey allow teams to request measurements at any stoppage in play, with no li
# 	Updating section with ID 59da63f83d3d24f5118c3340843a7b78b25a73e4 with summary and embedding...
# Summarized 151 characters. Here's a preview...
# 	A team may request a stick measurement prior to a penalty shot, leading to penalties ranging from bench minors to miscon
# 	Updating section with ID 009c36f07abdf0a5aaee0140577d4d84f122a37f with summary and embedding...
# Summarized 46 characters. Here's a preview...
# 	The rule does not apply at IIHF Championships.
# 	Updating section with ID 98c34e84c030600984030cd9fdc464f0ff47a074 with summary and embedding...
# Summarized 161 characters. Here's a preview...
# 	Goalkeepers' equipment must be solely for protection, providing no undue assistance in keeping goal, and are subject to
# 	Updating section with ID 1cb74283486293f9e30518754b7d3550a2ab71d4 with summary and embedding...
# Summarized 139 characters. Here's a preview...
# 	Goalkeeper equipment rules prohibit certain materials, designs, and attachments, while also regulating pad colors and le
# 	Updating section with ID 6113951a582188fed1d40fe24a3a9c81934c2e99 with summary and embedding...
# Summarized 203 characters. Here's a preview...
# 	Goalkeepers' chest and arm protectors must be anatomically proportional, size-specific, and conform to specific guidelin
# 	Updating section with ID 3492e240d9cfcf3c93c0d1d48573f06a742f2042 with summary and embedding...
# Summarized 199 characters. Here's a preview...
# 	Goalkeeper pants must be anatomically proportional and size-specific, with no padding beyond what's required for protect
# 	Updating section with ID 19bf106a3cfe275a8cca36dd788f85e313217f02 with summary and embedding...
# Summarized 129 characters. Here's a preview...
# 	Knee protection must be strapped, fit under thigh pads, and allow for unobstructed view of the "five hole" area between
# 	Updating section with ID 910f5cc3fc33046bb88bf6e05993f6c9b853183a with summary and embedding...
# Summarized 180 characters. Here's a preview...
# 	The specifications for a glove require its interior trap to be no more than 46 cm long, with a maximum perimeter of 114.
# 	Updating section with ID 393f5b2495b293147258d6dda7229ee5c7fbd55f with summary and embedding...
# Summarized 164 characters. Here's a preview...
# 	Goalkeeper's blocking gloves must adhere to specific measurements, including width, length, and thumb protection, with n
# 	Updating section with ID 3301914b433f3ddb1bbf0120c7edf7bed0a0e763 with summary and embedding...
# Summarized 195 characters. Here's a preview...
# 	Goalkeepers in Women's Hockey, Men's Junior Under 20 and Under 18 categories must wear approved protective face masks at
# 	Updating section with ID a0f47a89cb3335bd53694b1954c7e67ebceef0c4 with summary and embedding...
# Summarized 214 characters. Here's a preview...
# 	The International Ice Hockey Federation (IIHF) conducts regular inspections of goalkeepers' equipment to ensure complian
# 	Updating section with ID e1553fae740c1567d273c7738a8e3989819d5e2d with summary and embedding...
# Summarized 159 characters. Here's a preview...
# 	Players who fail to comply with rules regarding gloves and protective equipment may face penalties, including minor, mis
# 	Updating section with ID 1285c9327c5698f8e82e5fd0d7ddf702cb2744bc with summary and embedding...
# Summarized 115 characters. Here's a preview...
# 	Elbow pads without a soft, sponge rubber-like outer layer at least 1.5 cm thick are considered dangerous equipment.
# 	Updating section with ID 6e55d95ea93c60ccb75fd16560d00095cc6701ba with summary and embedding...
# Summarized 170 characters. Here's a preview...
# 	The IIHF's equipment regulations are written to promote fair play and reserve the right to deem equipment ineligible if
# 	Updating section with ID 594c284500da63e414f200e355e0ea24c4db1644 with summary and embedding...
# Summarized 151 characters. Here's a preview...
# 	The IIHF conducts inspections at any time and can confiscate equipment deemed non-compliant or illegal, imposing penalti
# 	Updating section with ID 1f8eca214067d1db0b29a189895e94d28be9dc62 with summary and embedding...
# Summarized 150 characters. Here's a preview...
# 	The official hockey puck must meet specific dimensions and weight requirements, be approved by the IIHF, and feature lim
# 	Updating section with ID f8d280b4e49096e4508c63d22719f4507c7fb393 with summary and embedding...
# Summarized 134 characters. Here's a preview...
# 	The Home Team's Organizing Committee is responsible for providing and storing official pucks in a frozen condition at th
# 	Updating section with ID cbcce1e8880fa653450228584f7e9cf35fc281ee with summary and embedding...
# Summarized 139 characters. Here's a preview...
# 	A stray puck that appears during play does not stop the game, and play continues with the original puck until the curren
# 	Updating section with ID 4f4c77e128cdde74ffc40b730a240acc11e0bec5 with summary and embedding...
# Summarized 159 characters. Here's a preview...
# 	Players are responsible for maintaining their own clothing and equipment, and any necessary adjustments must be made out
# 	Updating section with ID f33a46daccf3ba121a2d79f14b963f1e3f89e17f with summary and embedding...
# Summarized 158 characters. Here's a preview...
# 	The referees will stop play and impose penalties on offending players or teams when infractions occur, including ejectio
# 	Updating section with ID 8bd2107f29b6c6ca96ab34299cf58e584ec95a7e with summary and embedding...
# Summarized 131 characters. Here's a preview...
# 	When a minor penalty is imposed, it is either served or washed out depending on whether a goal is scored by the non-offe
# 	Updating section with ID ab6bdbdff6b13b72b5a82f60d19d10f0bd96ec50 with summary and embedding...
# Summarized 142 characters. Here's a preview...
# 	When a goal is scored after certain types of penalties are committed, a double-minor penalty of 2 minutes is assessed to
# 	Updating section with ID 30cf90e8878901d2a0303c43e822327ada60fdbc with summary and embedding...
# Summarized 193 characters. Here's a preview...
# 	When a team is short-handed due to penalties and a new penalty is signaled, if a goal is scored before play can be stopp
# 	Updating section with ID 2cedfad97dbd67ef1abce56e0cdc59e25b0832f1 with summary and embedding...
# Summarized 163 characters. Here's a preview...
# 	The face-off after a penalty is awarded to one team and takes place in their end zone, unless an exception applies, such
# 	Updating section with ID 311f3b8bf99ff866c27e655fb0504e4c7253ddf4 with summary and embedding...
# Summarized 143 characters. Here's a preview...
# 	A player, excluding the goalkeeper, who commits a minor penalty will be ejected from the game for 2 minutes without the
# 	Updating section with ID bcb741587aa5a87c2879e5d2570b7406002a37f2 with summary and embedding...
# Summarized 121 characters. Here's a preview...
# 	When a team is short-handed and an opposing team scores a goal, the first penalty to expire will automatically terminate
# 	Updating section with ID 5c5660b1fc81aa9f280f0ef5bee5ab4bdbfc71e3 with summary and embedding...
# Summarized 120 characters. Here's a preview...
# 	A Minor Penalty can be assessed for infractions listed in Table 2, according to Appendix IV – Tables Overview – Table 2.
# 	Updating section with ID d0974c47d9ddbe0a16fb47aa78b79571f3d2b3b6 with summary and embedding...
# Summarized 151 characters. Here's a preview...
# 	A Bench Minor Penalty involves removing one player from the ice for 2 minutes, allowing any non-goalie team member to se
# 	Updating section with ID e7c7e0fa4c57c343f68b965256fa3f76148008dd with summary and embedding...
# Summarized 134 characters. Here's a preview...
# 	In golf, "short-handed" refers to a situation where a player has fewer than five clubs in their bag due to loss or damag
# 	Updating section with ID a17086390dd51aabd79b26f26810917b8c07a991 with summary and embedding...
# Summarized 108 characters. Here's a preview...
# 	A Bench Minor Penalty can be assessed for various infractions listed in Table 3, as outlined in Appendix IV.
# 	Updating section with ID 3114f4384f81bb9aa7d8ab132ec4961976f91bd5 with summary and embedding...
# Summarized 150 characters. Here's a preview...
# 	A player, excluding the goalkeeper, who commits a double-minor penalty will be ejected from the game for 4 minutes witho
# 	Updating section with ID 9322e05d49fc0f6c29f17f10586afde2cb068793 with summary and embedding...
# Summarized 191 characters. Here's a preview...
# 	A non-offending team's goal during a delayed Double-minor Penalty results in one Minor Penalty being nullified, leaving
# 	Updating section with ID eea034be5f8772eac404b74b9702573c306863e0 with summary and embedding...
# Summarized 121 characters. Here's a preview...
# 	A Double-minor Penalty can be assessed for infractions listed in Table 4, according to the rules outlined in Appendix IV
# 	Updating section with ID 4b57b67a3379f9166f2e77417dfa8e73091f01a2 with summary and embedding...
# Summarized 177 characters. Here's a preview...
# 	The Video Review Operation communicates only with On-ice Officials, providing requested replays and angles, while Refere
# 	Updating section with ID 9affd5c0d74bd0933a7d12508afc177486010f5c with summary and embedding...
# Summarized 257 characters. Here's a preview...
# 	When multiple penalties are assessed to both teams, coincidental penalties are eliminated and any differential in time p
# 	Updating section with ID 33464b196cfbfee1bc9889b7283eecd6de480218 with summary and embedding...
# Summarized 218 characters. Here's a preview...
# 	When coincidental major penalties or penalties of equal duration are imposed, teams make immediate substitutions and pen
# 	Updating section with ID b33233f7d6cec801f09d1a8c7fe12c91163f07dc with summary and embedding...
# Summarized 201 characters. Here's a preview...
# 	When multiple penalties are assessed to both teams at the same stoppage of play, the differential will be recorded on th
# 	Updating section with ID 5d7591b30113de540c645624754d0ee041074101 with summary and embedding...
# Summarized 160 characters. Here's a preview...
# 	A Major Penalty in hockey results in a 5-minute penalty for physical fouls that recklessly endanger another player, with
# 	Updating section with ID 68d6d3b63f23631a82055f2873140c81ec7d11fc with summary and embedding...
# Summarized 142 characters. Here's a preview...
# 	A player serving a major penalty remains in the penalty box until their full penalty time expires, even if their team sc
# 	Updating section with ID 55d61857080e9586f53037fc0c199b08f211ae7a with summary and embedding...
# Summarized 111 characters. Here's a preview...
# 	The offending team must replace the ejected or injured player with a substitute in the penalty box immediately.
# 	Updating section with ID af8b2cbfe30f52a979d9fce6d08ff30c731d731e with summary and embedding...
# Summarized 154 characters. Here's a preview...
# 	A player who receives a second major penalty or misconduct penalty in the same game will automatically be ruled off the
# 	Updating section with ID 7ecd79598d649cb124f629965dcd3221f7226df9 with summary and embedding...
# Summarized 73 characters. Here's a preview...
# 	A Major Penalty can result from infractions listed in Tables 5, 6, and 7.
# 	Updating section with ID 18e98f50a05106e6a12af27d5de42983df2c72c7 with summary and embedding...
# Summarized 223 characters. Here's a preview...
# 	In certain IIHF Championships, Referees can review their own Major Penalty calls using video technology to confirm or mo
# 	Updating section with ID 0d76b721a3959173d04d5630b9d71ce00da22823 with summary and embedding...
# Summarized 130 characters. Here's a preview...
# 	The Referee must report all major penalties and their surrounding circumstances to the proper authorities promptly after
# 	Updating section with ID dfe278803c41cafb218d61fbf6bf84729604778a with summary and embedding...
# Summarized 171 characters. Here's a preview...
# 	A player who commits an action that endangers anyone involved in the game will receive a Major Penalty and automatic Gam
# 	Updating section with ID cb27632e4f24227d8e74810802a88ed098c4abb4 with summary and embedding...
# Summarized 163 characters. Here's a preview...
# 	Players serving misconduct penalties, excluding goalkeepers, are automatically ruled off the ice for 10 minutes, with th
# 	Updating section with ID 0d0249418dae20f9ab84426a5b8fb285e47dc995 with summary and embedding...
# Summarized 165 characters. Here's a preview...
# 	A goalkeeper's misconduct penalty will be served by a designated teammate, chosen by the coach through the captain, who
# 	Updating section with ID a42123dee5c18f1ae53fcac67d959b4503cef0f9 with summary and embedding...
# Summarized 151 characters. Here's a preview...
# 	A player receiving a misconduct penalty does not automatically put their team on short-handed status unless they also re
# 	Updating section with ID 1250595c4fef1cad10217c6297a4a80dc2b1e7ef with summary and embedding...
# Summarized 129 characters. Here's a preview...
# 	All misconduct penalties related to "Abuse of Officials" must be thoroughly documented and submitted to the relevant aut
# 	Updating section with ID 48bf0e81d2e02c7352ebcbd631d6eb3a7297ba0c with summary and embedding...
# Summarized 107 characters. Here's a preview...
# 	A Misconduct Penalty can be assessed for various infractions listed in Table 9, as outlined in Appendix IV.
# 	Updating section with ID eae521da00d11139d76072518f68f4f2aa0ab91f with summary and embedding...
# Summarized 199 characters. Here's a preview...
# 	A Game Misconduct Penalty results in the suspension of a player for the remainder of the game, with a 20-minute penalty
# 	Updating section with ID 7b5f7fad93471eb00f1472da164cc008daa88bac with summary and embedding...
# Summarized 172 characters. Here's a preview...
# 	Game Misconduct Penalties can be assessed for various infractions, including physical interference with spectators, raci
# 	Updating section with ID f0720e7cb10aba2950c2661465e1e800fba7fa1a with summary and embedding...
# Summarized 117 characters. Here's a preview...
# 	A Penalty Shot is a special play that gives the non-offending team an opportunity to score after a foul is committed.
# 	Updating section with ID ef4b27ab205bef2d30756c0484f1ca57f63c5393 with summary and embedding...
# Summarized 163 characters. Here's a preview...
# 	A penalty shot is awarded when a player is denied a clear scoring opportunity, allowing them to attempt to score on the
# 	Updating section with ID aa9f009c37ba6362a85a6145f6389a03665508b2 with summary and embedding...
# Summarized 147 characters. Here's a preview...
# 	A penalty shot is taken by a skater selected by the coach or captain of the non-offending team, chosen from any non-pena
# 	Updating section with ID 1462893e2344eec81510a95a6e2811603f6220b8 with summary and embedding...
# Summarized 141 characters. Here's a preview...
# 	If an opposing team or player interferes with a penalty shot during its taking, the shot can be re-taken if it fails due
# 	Updating section with ID da96035d588b05d966a6d30a0256a4b8ea6d6d70 with summary and embedding...
# Summarized 188 characters. Here's a preview...
# 	After a penalty shot attempt, the face-off will be held at center ice if a goal is scored, and at one of the end face-of
# 	Updating section with ID 1a41bbc799f1b9cf35c383328784d31f6e6d01f7 with summary and embedding...
# Summarized 179 characters. Here's a preview...
# 	A penalty shot does not reset the clock if a goal is scored against the opposing team, and only one goal can be scored f
# 	Updating section with ID 557ea20555a844913f2945f8a30919fe3806ebc6 with summary and embedding...
# Summarized 124 characters. Here's a preview...
# 	A penalty shot is awarded and taken immediately, regardless of delays, and does not affect regular playing time or overt
# 	Updating section with ID 5302c1411fcf26a51dd84f13dc5c91ff8a019a93 with summary and embedding...
# Summarized 212 characters. Here's a preview...
# 	A Penalty Shot is awarded when an attacking player is fouled from behind in the neutral or attacking zone, denied a reas
# 	Updating section with ID 3342f9a6fa4b47dd529ce28d72c5291ee36c25b8 with summary and embedding...
# Summarized 214 characters. Here's a preview...
# 	A goal will be awarded when an attacking player has possession and control in the neutral or attacking zone without a de
# 	Updating section with ID 6dbcb9e5c13702ceca19047c416645bad4b89395 with summary and embedding...
# Summarized 259 characters. Here's a preview...
# 	A goal will be awarded when an attacking player's scoring opportunity is thwarted by a defending player intentionally or
# 	Updating section with ID 98d31d2ea0dc7a4c93b10ad9dfe9ecec67e81740 with summary and embedding...
# Summarized 132 characters. Here's a preview...
# 	The removal of a goalkeeper for an extra attacker can lead to an awarded goal if certain infractions occur, as outlined
# 	Updating section with ID 7f1427f81751c5049e22b29172f8452b15e88542 with summary and embedding...
# Summarized 167 characters. Here's a preview...
# 	A goal will be awarded if a goalkeeper attempts to stop a penalty shot by using their stick or another object in a way t
# 	Updating section with ID b6db42f6dc370348eca646546a332d38a1e325cc with summary and embedding...
# Summarized 198 characters. Here's a preview...
# 	When multiple players from the same team are serving penalties simultaneously, the captain designates which player will
# 	Updating section with ID 8706687692eed5f3ca6963c795578cbecaa560d6 with summary and embedding...
# Summarized 176 characters. Here's a preview...
# 	Penalized players can only return to the ice when play has stopped and their penalty has fully expired, unless their tea
# 	Updating section with ID ae5b336056fed907bad78b1b28fb3cdf21421b34 with summary and embedding...
# Summarized 141 characters. Here's a preview...
# 	When both a major and minor penalty are given to players from the same team simultaneously, the minor penalty is recorde
# 	Updating section with ID 32e9408e1a4c83edfc3f3a15c3d32f1d21e2a95e with summary and embedding...
# Summarized 177 characters. Here's a preview...
# 	A goalkeeper cannot receive a minor penalty and must have another team member serve it, unless involved in coincidental
# 	Updating section with ID 15c96423dd44481791ce165bbc3931a588b25364 with summary and embedding...
# Summarized 179 characters. Here's a preview...
# 	A Goalkeeper serving a Major Penalty must have another team member serve it immediately, unless they incur a Game Miscon
# 	Updating section with ID d8a9f55f8728ca283f1910c6a0985ed1e569ab60 with summary and embedding...
# Summarized 143 characters. Here's a preview...
# 	A goalkeeper's misconduct penalty will be served by another team member who was on the ice at the time, designated by th
# 	Updating section with ID 849b9268bba9376b5eb15a1d671f3336cc01d4dd with summary and embedding...
# Summarized 151 characters. Here's a preview...
# 	A goalkeeper who incurs a game misconduct penalty will be replaced by a teammate or substitute goalkeeper, who can use t
# 	Updating section with ID f03efba810b65c965a27bfd3eb597735e241a592 with summary and embedding...
# Summarized 242 characters. Here's a preview...
# 	A Goalkeeper must obtain permission from the Referee to leave the crease for certain reasons, and may not be assessed a
# 	Updating section with ID b1c6323d79981497a4e277fd4e47bd808e355944 with summary and embedding...
# Summarized 176 characters. Here's a preview...
# 	A goalkeeper who participates in play beyond the center red line will receive a minor penalty unless they are attempting
# 	Updating section with ID b5d9df7992000178ec459d25b779ec88154a06ce with summary and embedding...
# Summarized 237 characters. Here's a preview...
# 	A goalie can play the puck without penalty as long as they maintain skate contact with their crease or stay within the d
# 	Updating section with ID b72a94612d7d70e3ef9251a17b1f8374c66b11c1 with summary and embedding...
# Summarized 69 characters. Here's a preview...
# 	The Goalkeeper may face penalties for infractions listed in Table 13.
# 	Updating section with ID 7b77265e14b9a41f3fc7013d16d71419ef7f5fcf with summary and embedding...
# Summarized 203 characters. Here's a preview...
# 	The IIHF may investigate and impose disciplinary measures for incidents occurring during games, practices, or exhibition
# 	Updating section with ID 22d15730f996e85b4f67228e4023e2be749e3830 with summary and embedding...
# Summarized 127 characters. Here's a preview...
# 	Supplementary discipline rules apply to pre-championship games and exhibition games, as outlined in the IIHF Disciplinar
# 	Updating section with ID 35b0770d1dcd9f1109bb134efcb778b5c1f61cc7 with summary and embedding...
# Summarized 87 characters. Here's a preview...
# 	The compilation and explanations of game officials' signals can be found in Appendix I.
# 	Updating section with ID 5fe07914c31747ecfc2af4f1fb779b6d3a985f7c with summary and embedding...
# Summarized 69 characters. Here's a preview...
# 	The IIHF will appoint all on-ice and off-ice officials for each game.
# 	Updating section with ID c60a12f7f57b74e996bee08e3b6411ff6e7000cb with summary and embedding...
# Summarized 114 characters. Here's a preview...
# 	Referees must wear black pants, IIHF-approved jerseys, helmets, and protective gear, along with official whistles.
# 	Updating section with ID ac38f354575b010d5b4477fc4ac79e41938b5713 with summary and embedding...
# Summarized 172 characters. Here's a preview...
# 	The Referees have final say in resolving disputes and making decisions, including using video review assistance, and the
# 	Updating section with ID 7063fe969a8f0a56475a5fdbf436c4734e78a4fe with summary and embedding...
# Summarized 123 characters. Here's a preview...
# 	The referee starts each period by "facing off" the puck, while linespersons handle all other face-offs throughout the ga
# 	Updating section with ID 307ee2dd6dba58ff2add0c0a574bde9e5a0370a4 with summary and embedding...
# Summarized 176 characters. Here's a preview...
# 	Referees are responsible for enforcing rules and making on-ice decisions, including determining penalties and disputed g
# 	Updating section with ID d14fda427628d1130a310843a659075f0161e89b with summary and embedding...
# Summarized 196 characters. Here's a preview...
# 	In the event of an incorrect goal signal light activation, the Referees will stop play, report the goal scorer and any a
# 	Updating section with ID 8b6e96218c0e0e9adce89e41bdc3f43c484080ec with summary and embedding...
# Summarized 170 characters. Here's a preview...
# 	The referee's announcements of penalties will accurately report the infraction and prioritize the visiting team's player
# 	Updating section with ID f7621d3c1be59f15c19d1e4340f1edc97a59533a with summary and embedding...
# Summarized 103 characters. Here's a preview...
# 	Referees ensure players are properly dressed and equipped according to regulations throughout the game.
# 	Updating section with ID d8dce5b4142406b346aa5f740dcbc29026bef657 with summary and embedding...
# Summarized 173 characters. Here's a preview...
# 	The Referee must promptly and thoroughly report to authorities any incidents involving misconduct penalties, altercation
# 	Updating section with ID f86d172d0e6e85cbdb875b82aa34423a2010be87 with summary and embedding...
# Summarized 147 characters. Here's a preview...
# 	The Referees or Official Timekeeper control game start times, manage intermissions, and ensure teams exit the ice surfac
# 	Updating section with ID 717e376b75cfaaa791a542ff7bd41bb807d8291a with summary and embedding...
# Summarized 165 characters. Here's a preview...
# 	If a referee leaves the ice or becomes injured during play, the game will automatically stop and either a standby offici
# 	Updating section with ID 00a0581977f531f52cc9809d659af34d18432770 with summary and embedding...
# CPU times: user 6.1 s, sys: 736 ms, total: 6.84 s
# Wall time: 11min 57s

# %% [markdown]
# ### To view the summaries for one `Section` node
#
# ```
# MATCH (c:Chunk)<-[:CONTAINS]-(s:Section)
# WHERE c.header4 = '8.1. INJURED PLAYER'
#     RETURN c, s
# ```

# %% [markdown]
# ### Remove all summary and summaryEmbedding from all `Section` nodes

# %%
cypher_remove_summaries = """
MATCH (s:Section) remove s.summary, s.summaryEbedding
"""

gdb.execute_query(cypher_remove_summaries)
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0xffff52c7bb90>, keys=[])
